# %% [markdown]
# #LSTM and ARIMA with CCI (Commodity Channel Index) technical indicator

# %% [markdown]
# **Students:** Gabriel Sposito and Thomas Frentzel

# %% [markdown]
# **LSTM**

# %%
# !pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=64df999936bbe4be16d44a6ac87a61136bf4f03184c97e7c97f06b036f1a3a40
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator

# %%
base = pd.read_csv('NVDA 5Y.csv')
base.head()
# Out:
#          Date Close/Last     Volume     Open     High        Low
# 0  10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1  10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2  10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3  10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4  10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14

# %%
#Removing nule results
base.dropna()
# Out:
#             Date Close/Last     Volume     Open     High        Low
# 0     10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1     10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2     10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3     10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4     10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14
# ...          ...        ...        ...      ...      ...        ...
# 1253  10/15/2019    $4.9093  667985200   $4.754  $4.9823      $4.74
# 1254  10/14/2019    $4.6633  210335760   $4.641  $4.6843    $4.6096
# 1255  10/11/2019    $4.6498  450866800  $4.6603  $4.7335    $4.6413
# 1256  10/10/2019    $4.5758  327515560  $4.5155   $4.627    $4.5103
# 1257  10/09/2019    $4.5178  307883280   $4.508  $4.5675     $4.479
#
# [1258 rows x 6 columns]

# %%
# Removing $
base['Close/Last'] = base['Close/Last'].str.replace('$', '')
base['Open'] = base['Open'].str.replace('$', '')
base['High'] = base['High'].str.replace('$', '')
base['Low'] = base['Low'].str.replace('$', '')

# Converting str to float
base['Close/Last'] = base['Close/Last'].astype(float)
base['Open'] = base['Open'].astype(float)
base['High'] = base['High'].astype(float)
base['Low'] = base['Low'].astype(float)

# %%
cci = CCIIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'], window=20, constant=0.015)
base['CCI'] = cci.cci()

sma_tp = base['High'] + base['Low'] + base['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base['Close/Last'], window=14)
base['RSI'] = rsi.rsi()

macd = MACD(close=base['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base['MACD'] = macd.macd()
base['MACD_Signal'] = macd.macd_signal()
base['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'])
base['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base['Close/Last'], window=20, window_dev=2)
base['Bollinger_High'] = bollinger.bollinger_hband()
base['Bollinger_Low'] = bollinger.bollinger_lband()
base['Bollinger_Middle'] = bollinger.bollinger_mavg()
base['Bollinger_Width'] = bollinger.bollinger_wband()

base.dropna()
# Out:
#             Date  Close/Last     Volume      Open      High       Low  \
# 33    08/21/2024    128.5000  257883600  127.3150  129.3500  126.6600
# 34    08/20/2024    127.2500  300087400  128.4000  129.8800  125.8900
# 35    08/19/2024    130.0000  318333600  124.2800  130.0000  123.4200
# 36    08/16/2024    124.5800  302589900  121.9400  125.0000  121.1800
# 37    08/15/2024    122.8600  318086700  118.7600  123.2400  117.4700
# ...          ...         ...        ...       ...       ...       ...
# 1253  10/15/2019      4.9093  667985200    4.7540    4.9823    4.7400
# 1254  10/14/2019      4.6633  210335760    4.6410    4.6843    4.6096
# 1255  10/11/2019      4.6498  450866800    4.6603    4.7335    4.6413
# 1256  10/10/2019      4.5758  327515560    4.5155    4.6270    4.5103
# 1257  10/09/2019      4.5178  307883280    4.5080    4.5675    4.4790
#
#              CCI        RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    109.563550  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34     93.439821  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35     85.454132  60.187685  2.240879     0.121107   2.119773     118.873314
# 36     43.621331  53.180795  2.132257     0.523337   1.608920     120.359716
# 37     20.947193  51.145899  1.885647     0.795799   1.089848     131.260000
# ...          ...        ...       ...          ...        ...            ...
# 1253  -81.288448  39.738294 -0.131057    -0.128466  -0.002591       4.993934
# 1254 -167.078542  30.794457 -0.143643    -0.131501  -0.012142       4.980500
# 1255 -137.142137  30.390224 -0.152944    -0.135790  -0.017154       4.982300
# 1256 -162.944078  28.204663 -0.164391    -0.141510  -0.022881       4.937576
# 1257 -163.280746  26.590538 -0.176113    -0.148431  -0.027683       4.877757
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33        133.280229     100.584771        116.932500        27.960967
# 34        134.480982     100.772018        117.626500        28.657628
# 35        136.004529     100.689471        118.347000        29.840264
# 36        136.582416     100.891584        118.737000        30.058729
# 37        136.860746     100.989254        118.925000        30.163121
# ...              ...            ...               ...              ...
# 1253        5.343533       4.736087          5.039810        12.052969
# 1254        5.347782       4.677718          5.012750        13.367186
# 1255        5.344708       4.626322          4.985515        14.409444
# 1256        5.339425       4.568335          4.953880        15.565376
# 1257        5.333658       4.506802          4.920230        16.805226
#
# [1225 rows x 16 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(base['CCI'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base['Close/Last'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base = base.replace([np.inf, -np.inf], np.nan)
base = base.dropna()

# %%
# Normalizing the data of real values
scaler_real_value = MinMaxScaler(feature_range=(0, 1))
scaled_data_real_value = scaler_real_value.fit_transform(np.array(base['Close/Last']).reshape(-1, 1))

# %%
window_size_real_value = 10
forecasters_real_value = []
real_value_of_prices = []
for i in range(window_size_real_value, len(base)):
    forecasters_real_value.append(scaled_data_real_value[i - window_size_real_value:i, 0])
    real_value_of_prices.append(scaled_data_real_value[i, 0])

forecasters_real_value, real_value_of_prices = np.array(forecasters_real_value), np.array(real_value_of_prices)
forecasters_real_value = np.reshape(forecasters_real_value, (forecasters_real_value.shape[0], forecasters_real_value.shape[1], 1))

# %%
#dividindo a coluna close/last em 70% treino e 30% teste com trai_test_split
Xtrain_real_lstm, Xtest_real_lstm, ytrain_real_lstm, ytest_real_lstm = train_test_split(forecasters_real_value, real_value_of_prices,
                                                                                        test_size = 0.3, shuffle = False)

# %%
#plotando grafico dos valores de teste
plt.figure(figsize=(16,8))
plt.plot(ytest_real_lstm)
plt.show()

# %%
# Normalizing the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(base['CCI']).reshape(-1, 1))

# %%
window_size = 10
forecasters = []
real_value = []
for i in range(window_size, len(base)):
    forecasters.append(scaled_data[i - window_size:i, 0])
    real_value.append(scaled_data[i, 0])

forecasters, real_value = np.array(forecasters), np.array(real_value)
forecasters = np.reshape(forecasters, (forecasters.shape[0], forecasters.shape[1], 1))

# %%
# Separating data between training and testing
X_train, X_test, y_train, y_test = train_test_split(forecasters, real_value, test_size=0.3, shuffle=False)

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test)
plt.show()

# %%
# LSTM model

lstm = Sequential()
lstm.add(LSTM(units=50, return_sequences=True, input_shape=(forecasters.shape[1], 1)))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50, return_sequences=True))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50))
lstm.add(Dropout(0.3))
lstm.add(Dense(units=1))
lstm.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = lstm.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 0.1413 - mean_absolute_error: 0.3209 - val_loss: 0.0220 - val_mean_absolute_error: 0.1136
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0253 - mean_absolute_error: 0.1252 - val_loss: 0.0176 - val_mean_absolute_error: 0.1039
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0250 - mean_absolute_error: 0.1265 - val_loss: 0.0174 - val_mean_absolute_error: 0.1029
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0233 - mean_absolute_error: 0.1225 - val_loss: 0.0171 - val_mean_absolute_error: 0.1016
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0219 - mean_absolute_error: 0.1199 - val_loss: 0.0170 - val_mean_absolute_error: 0.1019
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0213 - mean_absolute_error: 0.1153 - val_loss: 0.0166 - val_mean_absolute_error: 0.1000
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0202 - mean_absolute_error: 0.1118 - val_loss: 0.0162 - val_mean_absolute_error: 0.0987
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0190 - mean_absolute_error: 0.1069 - val_loss: 0.0161 - val_mean_absolute_error: 0.0984
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0195 - mean_absolute_error: 0.1099 - val_loss: 0.0155 - val_mean_absolute_error: 0.0950
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0171 - mean_absolute_error: 0.1010 - val_loss: 0.0151 - val_mean_absolute_error: 0.0929
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0180 - mean_absolute_error: 0.1026 - val_loss: 0.0160 - val_mean_absolute_error: 0.0946
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0164 - mean_absolute_error: 0.1011 - val_loss: 0.0139 - val_mean_absolute_error: 0.0883
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0155 - mean_absolute_error: 0.0959 - val_loss: 0.0148 - val_mean_absolute_error: 0.0916
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0159 - mean_absolute_error: 0.0984 - val_loss: 0.0145 - val_mean_absolute_error: 0.0891
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0153 - mean_absolute_error: 0.0951 - val_loss: 0.0134 - val_mean_absolute_error: 0.0843
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0124 - mean_absolute_error: 0.0849 - val_loss: 0.0138 - val_mean_absolute_error: 0.0862
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0140 - mean_absolute_error: 0.0909 - val_loss: 0.0128 - val_mean_absolute_error: 0.0818
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0132 - mean_absolute_error: 0.0868 - val_loss: 0.0131 - val_mean_absolute_error: 0.0832
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0134 - mean_absolute_error: 0.0889 - val_loss: 0.0128 - val_mean_absolute_error: 0.0815
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0145 - mean_absolute_error: 0.0929 - val_loss: 0.0125 - val_mean_absolute_error: 0.0810
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0121 - mean_absolute_error: 0.0860 - val_loss: 0.0122 - val_mean_absolute_error: 0.0796
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0142 - mean_absolute_error: 0.0894 - val_loss: 0.0117 - val_mean_absolute_error: 0.0771
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0123 - mean_absolute_error: 0.0856 - val_loss: 0.0116 - val_mean_absolute_error: 0.0770
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0110 - mean_absolute_error: 0.0803 - val_loss: 0.0116 - val_mean_absolute_error: 0.0771
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - mean_absolute_error: 0.0857 - val_loss: 0.0114 - val_mean_absolute_error: 0.0765
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0113 - mean_absolute_error: 0.0817 - val_loss: 0.0107 - val_mean_absolute_error: 0.0732
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0106 - mean_absolute_error: 0.0797 - val_loss: 0.0106 - val_mean_absolute_error: 0.0730
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0102 - mean_absolute_error: 0.0775 - val_loss: 0.0103 - val_mean_absolute_error: 0.0719
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0105 - mean_absolute_error: 0.0803 - val_loss: 0.0111 - val_mean_absolute_error: 0.0758
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0099 - mean_absolute_error: 0.0755 - val_loss: 0.0101 - val_mean_absolute_error: 0.0714
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0104 - mean_absolute_error: 0.0758 - val_loss: 0.0093 - val_mean_absolute_error: 0.0678
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0094 - mean_absolute_error: 0.0743 - val_loss: 0.0093 - val_mean_absolute_error: 0.0681
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0101 - mean_absolute_error: 0.0751 - val_loss: 0.0088 - val_mean_absolute_error: 0.0660
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0108 - mean_absolute_error: 0.0778 - val_loss: 0.0090 - val_mean_absolute_error: 0.0670
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0099 - mean_absolute_error: 0.0757 - val_loss: 0.0083 - val_mean_absolute_error: 0.0638
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0088 - mean_absolute_error: 0.0710 - val_loss: 0.0082 - val_mean_absolute_error: 0.0636
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0093 - mean_absolute_error: 0.0748 - val_loss: 0.0079 - val_mean_absolute_error: 0.0624
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0081 - mean_absolute_error: 0.0678 - val_loss: 0.0079 - val_mean_absolute_error: 0.0619
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0082 - mean_absolute_error: 0.0686 - val_loss: 0.0075 - val_mean_absolute_error: 0.0603
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0086 - mean_absolute_error: 0.0696 - val_loss: 0.0076 - val_mean_absolute_error: 0.0614
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0084 - mean_absolute_error: 0.0708 - val_loss: 0.0086 - val_mean_absolute_error: 0.0672
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0084 - mean_absolute_error: 0.0705 - val_loss: 0.0073 - val_mean_absolute_error: 0.0599
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0079 - mean_absolute_error: 0.0671 - val_loss: 0.0070 - val_mean_absolute_error: 0.0586
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0078 - mean_absolute_error: 0.0658 - val_loss: 0.0070 - val_mean_absolute_error: 0.0582
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0088 - mean_absolute_error: 0.0692 - val_loss: 0.0067 - val_mean_absolute_error: 0.0570
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0076 - mean_absolute_error: 0.0665 - val_loss: 0.0066 - val_mean_absolute_error: 0.0562
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0071 - mean_absolute_error: 0.0621 - val_loss: 0.0068 - val_mean_absolute_error: 0.0579
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0083 - mean_absolute_error: 0.0695 - val_loss: 0.0073 - val_mean_absolute_error: 0.0619
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0083 - mean_absolute_error: 0.0674 - val_loss: 0.0062 - val_mean_absolute_error: 0.0546
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0075 - mean_absolute_error: 0.0653 - val_loss: 0.0062 - val_mean_absolute_error: 0.0542
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0074 - mean_absolute_error: 0.0651 - val_loss: 0.0061 - val_mean_absolute_error: 0.0536
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0067 - mean_absolute_error: 0.0613 - val_loss: 0.0062 - val_mean_absolute_error: 0.0549
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0064 - mean_absolute_error: 0.0592 - val_loss: 0.0061 - val_mean_absolute_error: 0.0543
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0066 - mean_absolute_error: 0.0627 - val_loss: 0.0060 - val_mean_absolute_error: 0.0530
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0063 - mean_absolute_error: 0.0579 - val_loss: 0.0060 - val_mean_absolute_error: 0.0528
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0626 - val_loss: 0.0060 - val_mean_absolute_error: 0.0532
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0619 - val_loss: 0.0061 - val_mean_absolute_error: 0.0542
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0590 - val_loss: 0.0060 - val_mean_absolute_error: 0.0537
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0061 - mean_absolute_error: 0.0600 - val_loss: 0.0060 - val_mean_absolute_error: 0.0532
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0559 - val_loss: 0.0061 - val_mean_absolute_error: 0.0544
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0063 - mean_absolute_error: 0.0595 - val_loss: 0.0059 - val_mean_absolute_error: 0.0524
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0061 - mean_absolute_error: 0.0601 - val_loss: 0.0060 - val_mean_absolute_error: 0.0538
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mean_absolute_error: 0.0579 - val_loss: 0.0061 - val_mean_absolute_error: 0.0538
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0071 - mean_absolute_error: 0.0634 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0070 - mean_absolute_error: 0.0638 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0068 - mean_absolute_error: 0.0609 - val_loss: 0.0059 - val_mean_absolute_error: 0.0522
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0065 - mean_absolute_error: 0.0604 - val_loss: 0.0061 - val_mean_absolute_error: 0.0538
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0066 - mean_absolute_error: 0.0601 - val_loss: 0.0058 - val_mean_absolute_error: 0.0520
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0067 - mean_absolute_error: 0.0620 - val_loss: 0.0058 - val_mean_absolute_error: 0.0519
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0560 - val_loss: 0.0059 - val_mean_absolute_error: 0.0527
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0578 - val_loss: 0.0058 - val_mean_absolute_error: 0.0517
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0071 - mean_absolute_error: 0.0623 - val_loss: 0.0059 - val_mean_absolute_error: 0.0529
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0539 - val_loss: 0.0058 - val_mean_absolute_error: 0.0522
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0578 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0061 - mean_absolute_error: 0.0589 - val_loss: 0.0059 - val_mean_absolute_error: 0.0520
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0055 - mean_absolute_error: 0.0583 - val_loss: 0.0060 - val_mean_absolute_error: 0.0528
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0054 - mean_absolute_error: 0.0557 - val_loss: 0.0059 - val_mean_absolute_error: 0.0525
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - mean_absolute_error: 0.0527 - val_loss: 0.0058 - val_mean_absolute_error: 0.0519
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051 - mean_absolute_error: 0.0524 - val_loss: 0.0058 - val_mean_absolute_error: 0.0517
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0554 - val_loss: 0.0059 - val_mean_absolute_error: 0.0522
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0537 - val_loss: 0.0059 - val_mean_absolute_error: 0.0526
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0053 - mean_absolute_error: 0.0532 - val_loss: 0.0064 - val_mean_absolute_error: 0.0566
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0063 - mean_absolute_error: 0.0592 - val_loss: 0.0060 - val_mean_absolute_error: 0.0538
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0055 - mean_absolute_error: 0.0544 - val_loss: 0.0060 - val_mean_absolute_error: 0.0531
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0053 - mean_absolute_error: 0.0542 - val_loss: 0.0058 - val_mean_absolute_error: 0.0520
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0055 - mean_absolute_error: 0.0540 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0056 - mean_absolute_error: 0.0565 - val_loss: 0.0058 - val_mean_absolute_error: 0.0519
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0568 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0054 - mean_absolute_error: 0.0539 - val_loss: 0.0062 - val_mean_absolute_error: 0.0548
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0055 - mean_absolute_error: 0.0545 - val_loss: 0.0060 - val_mean_absolute_error: 0.0533
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0055 - mean_absolute_error: 0.0550 - val_loss: 0.0058 - val_mean_absolute_error: 0.0515
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0048 - mean_absolute_error: 0.0512 - val_loss: 0.0058 - val_mean_absolute_error: 0.0515
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0550 - val_loss: 0.0063 - val_mean_absolute_error: 0.0557
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0061 - mean_absolute_error: 0.0578 - val_loss: 0.0058 - val_mean_absolute_error: 0.0520
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0062 - mean_absolute_error: 0.0582 - val_loss: 0.0058 - val_mean_absolute_error: 0.0519
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0552 - val_loss: 0.0058 - val_mean_absolute_error: 0.0518
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0061 - mean_absolute_error: 0.0567 - val_loss: 0.0058 - val_mean_absolute_error: 0.0517
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0533 - val_loss: 0.0058 - val_mean_absolute_error: 0.0521
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0556 - val_loss: 0.0059 - val_mean_absolute_error: 0.0525
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0537 - val_loss: 0.0057 - val_mean_absolute_error: 0.0516

# %%
test_predictions = lstm.predict(X_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step

# %%
# Transforming test values ​​back to original values
y_orig_test = scaler.inverse_transform(y_test.reshape(-1, 1))

#escalonando valores de teste
ytest_real_lstm = scaler_real_value.inverse_transform(ytest_real_lstm.reshape(-1, 1))

# %%
test_predictions = test_predictions.ravel()
y_orig_test = y_orig_test.ravel()
ytest_real_lstm = ytest_real_lstm.ravel()

# %%
# Getting the high, low and close values ​​from the test set for the CCI
test_size_L = len(y_test)

high_test_L = base['High'].tail(test_size_L)
low_test_L = base['Low'].tail(test_size_L)
close_test_L = base['Close/Last'].tail(test_size_L)

# %%
# Inverse CCI formula
def cci_inverse(cci_values, high, low, close):
    tp = (high + low + close) / 3
    sma_tp = tp.rolling(window=20).mean()
    mean_deviation = (tp - sma_tp).abs().rolling(window=20).mean()
    tp_inverted = cci_values * 0.015 * mean_deviation + sma_tp
    return tp_inverted

# %%
# Inverting the values ​​test_predictions and y_orig_teste by the inverse CCI formula
test_predictions_inverted = cci_inverse(test_predictions, high_test_L, low_test_L, close_test_L)
y_orig_test_inverted = cci_inverse(y_orig_test, high_test_L, low_test_L, close_test_L)

# Removing NaN values
test_predictions_inverted = test_predictions_inverted.dropna()
y_orig_test_inverted = y_orig_test_inverted.dropna()

min_length = min(len(ytest_real_lstm), len(test_predictions_inverted))
ytest_real_lstm = ytest_real_lstm[:min_length]
test_predictions_inverted = test_predictions_inverted[:min_length]

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(ytest_real_lstm)), ytest_real_lstm, label='Real')
plt.plot(range(len(test_predictions_inverted)), test_predictions_inverted, label='Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# R2 Score
r2 = r2_score(ytest_real_lstm, test_predictions_inverted)
print(f'R2 Score: {r2}')

# RMSE
rmse = np.sqrt(np.mean((ytest_real_lstm - test_predictions_inverted) ** 2))
print(f'RMSE: {rmse}')
# Out:
# R2 Score: 0.717099035489581
# RMSE: 1.6728105056883666

# %% [markdown]
# **ARIMA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator
from math import sqrt

# %%
base_A = pd.read_csv('NVDA 5Y.csv')
base_A.head()
# Out:
#          Date Close/Last     Volume     Open     High        Low
# 0  10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1  10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2  10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3  10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4  10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14

# %%
base_A.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
# Removing $
base_A['Close/Last'] = base_A['Close/Last'].str.replace('$', '')
base_A['Open'] = base_A['Open'].str.replace('$', '')
base_A['High'] = base_A['High'].str.replace('$', '')
base_A['Low'] = base_A['Low'].str.replace('$', '')

# Converting str to float
base_A['Close/Last'] = base_A['Close/Last'].astype(float)
base_A['Open'] = base_A['Open'].astype(float)
base_A['High'] = base_A['High'].astype(float)
base_A['Low'] = base_A['Low'].astype(float)

# %%
cci = CCIIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'], window=20, constant=0.015)
base_A['CCI'] = cci.cci()

sma_tp = base_A['High'] + base_A['Low'] + base_A['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base_A['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base_A['Close/Last'], window=14)
base_A['RSI'] = rsi.rsi()

macd = MACD(close=base_A['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base_A['MACD'] = macd.macd()
base_A['MACD_Signal'] = macd.macd_signal()
base_A['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'])
base_A['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base_A['Close/Last'], window=20, window_dev=2)
base_A['Bollinger_High'] = bollinger.bollinger_hband()
base_A['Bollinger_Low'] = bollinger.bollinger_lband()
base_A['Bollinger_Middle'] = bollinger.bollinger_mavg()
base_A['Bollinger_Width'] = bollinger.bollinger_wband()

base_A.dropna()
# Out:
#             Date  Close/Last     Volume      Open      High       Low  \
# 33    08/21/2024    128.5000  257883600  127.3150  129.3500  126.6600
# 34    08/20/2024    127.2500  300087400  128.4000  129.8800  125.8900
# 35    08/19/2024    130.0000  318333600  124.2800  130.0000  123.4200
# 36    08/16/2024    124.5800  302589900  121.9400  125.0000  121.1800
# 37    08/15/2024    122.8600  318086700  118.7600  123.2400  117.4700
# ...          ...         ...        ...       ...       ...       ...
# 1253  10/15/2019      4.9093  667985200    4.7540    4.9823    4.7400
# 1254  10/14/2019      4.6633  210335760    4.6410    4.6843    4.6096
# 1255  10/11/2019      4.6498  450866800    4.6603    4.7335    4.6413
# 1256  10/10/2019      4.5758  327515560    4.5155    4.6270    4.5103
# 1257  10/09/2019      4.5178  307883280    4.5080    4.5675    4.4790
#
#              CCI        RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    109.563550  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34     93.439821  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35     85.454132  60.187685  2.240879     0.121107   2.119773     118.873314
# 36     43.621331  53.180795  2.132257     0.523337   1.608920     120.359716
# 37     20.947193  51.145899  1.885647     0.795799   1.089848     131.260000
# ...          ...        ...       ...          ...        ...            ...
# 1253  -81.288448  39.738294 -0.131057    -0.128466  -0.002591       4.993934
# 1254 -167.078542  30.794457 -0.143643    -0.131501  -0.012142       4.980500
# 1255 -137.142137  30.390224 -0.152944    -0.135790  -0.017154       4.982300
# 1256 -162.944078  28.204663 -0.164391    -0.141510  -0.022881       4.937576
# 1257 -163.280746  26.590538 -0.176113    -0.148431  -0.027683       4.877757
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33        133.280229     100.584771        116.932500        27.960967
# 34        134.480982     100.772018        117.626500        28.657628
# 35        136.004529     100.689471        118.347000        29.840264
# 36        136.582416     100.891584        118.737000        30.058729
# 37        136.860746     100.989254        118.925000        30.163121
# ...              ...            ...               ...              ...
# 1253        5.343533       4.736087          5.039810        12.052969
# 1254        5.347782       4.677718          5.012750        13.367186
# 1255        5.344708       4.626322          4.985515        14.409444
# 1256        5.339425       4.568335          4.953880        15.565376
# 1257        5.333658       4.506802          4.920230        16.805226
#
# [1225 rows x 16 columns]

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base_A = base_A.replace([np.inf, -np.inf], np.nan)
base_A = base_A.dropna()

# %%
base_A.head()
# Out:
#           Date  Close/Last     Volume     Open    High     Low         CCI  \
# 33  08/21/2024      128.50  257883600  127.315  129.35  126.66  109.563550
# 34  08/20/2024      127.25  300087400  128.400  129.88  125.89   93.439821
# 35  08/19/2024      130.00  318333600  124.280  130.00  123.42   85.454132
# 36  08/16/2024      124.58  302589900  121.940  125.00  121.18   43.621331
# 37  08/15/2024      122.86  318086700  118.760  123.24  117.47   20.947193
#
#           RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35  60.187685  2.240879     0.121107   2.119773     118.873314
# 36  53.180795  2.132257     0.523337   1.608920     120.359716
# 37  51.145899  1.885647     0.795799   1.089848     131.260000
#
#     Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33      133.280229     100.584771          116.9325        27.960967
# 34      134.480982     100.772018          117.6265        28.657628
# 35      136.004529     100.689471          118.3470        29.840264
# 36      136.582416     100.891584          118.7370        30.058729
# 37      136.860746     100.989254          118.9250        30.163121

# %%
plt.figure(figsize=(16,8))
plt.plot(base_A['CCI'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base_A['Close/Last'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
X_R = base_A['Close/Last'].values
size_R = int(len(X_R) * 0.70)
train_R, test_R = X_R[0:size_R], X_R[size_R:len(X_R)]
history_R = [x_r for x_r in train_R]
forecasts_R = list()

# %%
#Test Grafic
plt.figure(figsize=(16, 8))
plt.plot(test_R)
plt.show()

# %%
# Addfuller for CCI
result = adfuller(base_A['CCI'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -8.697055510834515
# p-value: 3.899246685056119e-14

# %%
plot_acf(base_A['CCI'], lags=40)
plt.show()

# %%
plot_pacf(base_A['CCI'], lags=40)
plt.show()

# %%
X = base_A['CCI'].values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
forecasts = list()

# %%
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.show()

# %%
# ARIMA
for t in range(len(test)):
    model = ARIMA(history, order=(2, 1, 1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    forecasts.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'Expected={yhat}, Observed={obs}')
# Out:
# Expected=-122.19472822215421, Observed=-129.95290816332488
# Expected=-118.63003456060383, Observed=-96.7776313804149
# Expected=-83.01259968327187, Observed=-67.67700278621122
# Expected=-57.70886462619974, Observed=-61.121023381915336
# Expected=-56.31435640220875, Observed=-80.52983206559728
# Expected=-78.9265683797192, Observed=-68.54294351660685
# Expected=-61.95404624457861, Observed=-31.50105741089803
# Expected=-23.7477116373341, Observed=-20.76514008671794
# Expected=-19.348664832521983, Observed=-41.020680370272196
# Expected=-43.6757972813497, Observed=-73.53556086347946
# Expected=-75.27222596423047, Observed=-47.34466808693854
# Expected=-40.11698423688921, Observed=-91.78448894116987
# Expected=-93.95210943383077, Observed=-129.45759484356225
# Expected=-126.47429205086037, Observed=-216.5335134857329
# Expected=-214.68030100759518, Observed=-138.65017623779102
# Expected=-111.9037440931985, Observed=-76.70173008728074
# Expected=-59.34606379639854, Observed=57.84696938130955
# Expected=76.15630822334256, Observed=166.55882878847441
# Expected=169.1066534546414, Observed=175.62641561713693
# Expected=156.32662366843078, Observed=130.2551398524022
# Expected=104.15592503556198, Observed=113.93320752559045
# Expected=95.73233780866616, Observed=183.76308863348046
# Expected=176.6419882929343, Observed=116.82929497271523
# Expected=88.04685446064089, Observed=172.72191678076777
# Expected=163.68278081761517, Observed=180.9570845253324
# Expected=161.48920062226634, Observed=134.66081981596918
# Expected=108.73719835151455, Observed=132.22345222033888
# Expected=115.64480567150831, Observed=132.87878566319947
# Expected=116.95307056436334, Observed=104.21214326137931
# Expected=85.26771182703129, Observed=102.13386523039831
# Expected=88.87521999358212, Observed=60.55194420385656
# Expected=43.51018983633351, Observed=32.92110379321305
# Expected=21.535057398468897, Observed=16.365082214897292
# Expected=8.932207346960244, Observed=-45.400904129624664
# Expected=-55.790140345749194, Observed=-64.66076565272837
# Expected=-64.41939020553731, Observed=-66.96813269203273
# Expected=-62.98312285226788, Observed=-95.54306360090436
# Expected=-94.14828891832553, Observed=-128.63494154454165
# Expected=-124.79417365246499, Observed=-123.44819520532516
# Expected=-112.32773615698727, Observed=-110.97318029075464
# Expected=-99.6725646336821, Observed=-115.30957952668707
# Expected=-107.01579918826249, Observed=-58.49913778485898
# Expected=-43.56104575715466, Observed=-47.59421700883424
# Expected=-43.16788829523005, Observed=-29.566409538437327
# Expected=-25.539072797959903, Observed=-27.12686893416101
# Expected=-26.511819820629732, Observed=-65.24301435986729
# Expected=-68.99237328043407, Observed=-93.23351333660634
# Expected=-92.04727655281627, Observed=-90.55609832193535
# Expected=-83.38020699158312, Observed=-43.73132879483454
# Expected=-32.361656452041096, Observed=-2.0707825117802576
# Expected=3.9738578879522706, Observed=14.404998239055578
# Expected=13.592459762124076, Observed=57.01160567060493
# Expected=57.281369586119894, Observed=-40.02523951850128
# Expected=-58.40545393352689, Observed=-47.295252902923146
# Expected=-46.583792735707824, Observed=-142.23074152813166
# Expected=-149.51445905473824, Observed=1.1616427372266558
# Expected=26.505282427045557, Observed=-16.582373962828118
# Expected=-21.029231755467716, Observed=-76.14832480907884
# Expected=-82.43933998407174, Observed=-62.67968803539712
# Expected=-56.28569818594091, Observed=-97.16558196186016
# Expected=-96.41840094254744, Observed=-107.32767647589789
# Expected=-100.83689765984619, Observed=-67.86634592460074
# Expected=-55.93401198804469, Observed=-41.22501680018773
# Expected=-34.55970390168504, Observed=5.2529591935311535
# Expected=10.894761711842172, Observed=15.276916146882837
# Expected=12.802685091604548, Observed=26.15760896118575
# Expected=22.737901401506818, Observed=41.417337276748704
# Expected=37.283164725183624, Observed=36.38407479565791
# Expected=28.815371899427873, Observed=52.866059572042246
# Expected=47.756755895145616, Observed=26.615229579036235
# Expected=15.991575580315494, Observed=-97.61696350417076
# Expected=-114.40612282716658, Observed=-82.83815814789688
# Expected=-74.00555227136266, Observed=-27.56667721493271
# Expected=-16.72364517809453, Observed=123.1517729854501
# Expected=137.37270836924995, Observed=192.0938896619755
# Expected=183.16094628703678, Observed=131.64763498179414
# Expected=102.78851066172717, Observed=103.67343242801721
# Expected=84.39559030568519, Observed=102.5762281746491
# Expected=88.92817327360831, Observed=57.44315782035377
# Expected=39.67519732513398, Observed=4.861132035405073
# Expected=-8.867761212823687, Observed=5.032484607232201
# Expected=1.9825847574040005, Observed=-52.60262704675677
# Expected=-61.2447237846147, Observed=-134.27730661773165
# Expected=-139.22581432735583, Observed=-44.304549040659865
# Expected=-24.122863181960042, Observed=-26.269705117754157
# Expected=-22.46535816619051, Observed=32.67089128203831
# Expected=38.43227397786863, Observed=58.71970252245344
# Expected=55.13625585111997, Observed=67.90348139079103
# Expected=60.012614248773566, Observed=63.2194941587209
# Expected=52.989050406533, Observed=19.330220040766037
# Expected=5.876533612852093, Observed=86.93765314038633
# Expected=88.727572941739, Observed=-38.17600877354949
# Expected=-61.12012576014527, Observed=-170.69408784099826
# Expected=-181.61214153295165, Observed=259.16988892879994
# Expected=303.55173580677905, Observed=321.53612583687897
# Expected=294.273664216285, Observed=206.3526654817572
# Expected=159.71714459829025, Observed=56.287321995028684
# Expected=19.544907538022244, Observed=-128.18697033383873
# Expected=-151.38063825739255, Observed=-175.40439397141162
# Expected=-166.0934390320602, Observed=-156.60701227084968
# Expected=-136.42386995260398, Observed=-67.52436763639352
# Expected=-43.87808507353455, Observed=-90.72147044382037
# Expected=-87.17600143617064, Observed=3.070659018925098
# Expected=18.82802186323636, Observed=-8.617542301163322
# Expected=-12.260819653120643, Observed=29.078012041011785
# Expected=30.51670747926868, Observed=10.254410436394016
# Expected=2.9661386959012894, Observed=46.288232244686114
# Expected=45.38369307169926, Observed=52.899364010475004
# Expected=45.48414257559749, Observed=45.85260405423825
# Expected=36.651625676594094, Observed=86.59190807462045
# Expected=81.87893376813638, Observed=79.99166639253477
# Expected=66.89933465529063, Observed=102.95498192978916
# Expected=92.90833513111234, Observed=103.61120961970411
# Expected=89.20569429333655, Observed=93.74483021595753
# Expected=78.53746525665196, Observed=38.330648909676654
# Expected=20.896896274594063, Observed=65.64122184923266
# Expected=61.14971768489731, Observed=74.82216735770936
# Expected=65.74016066965052, Observed=48.51429138099644
# Expected=35.69788500720128, Observed=-20.04047689868357
# Expected=-32.857431330133764, Observed=-92.23131188989865
# Expected=-97.21344909857129, Observed=-13.252682876984856
# Expected=1.8192231462790005, Observed=-69.96392490649588
# Expected=-74.33396191872953, Observed=-126.85773024471887
# Expected=-124.57287334863979, Observed=-177.66025259780454
# Expected=-168.32389501188302, Observed=-206.07513647342336
# Expected=-189.24557086909715, Observed=-223.96528636130896
# Expected=-203.24485722039705, Observed=-177.29406259375654
# Expected=-149.52079258136445, Observed=-127.89438805304204
# Expected=-105.42177174714698, Observed=-126.2552740013328
# Expected=-113.37494377358988, Observed=-114.18188376541006
# Expected=-100.77020862161577, Observed=-92.86880900488934
# Expected=-80.2245083913622, Observed=-49.6884886048162
# Expected=-37.927209868718904, Observed=-7.275439260280913
# Expected=-0.7010837693752023, Observed=-13.072238325704337
# Expected=-15.224783555353426, Observed=-95.77852915180571
# Expected=-103.071371739394, Observed=-53.092303248828436
# Expected=-41.0921004480643, Observed=-37.017521410310614
# Expected=-32.099987317967866, Observed=-113.09042262180238
# Expected=-116.93018379964595, Observed=-34.03002605902865
# Expected=-17.582806943046776, Observed=104.81768567152118
# Expected=116.62789959367369, Observed=261.53041287427806
# Expected=259.2640821649368, Observed=157.29581155767332
# Expected=114.87395728169626, Observed=89.04781841767479
# Expected=62.04245321065045, Observed=35.27989535643527
# Expected=17.761773310042024, Observed=-10.040657153705485
# Expected=-20.25327052470309, Observed=0.36498767082674843
# Expected=0.035162702197199636, Observed=-15.479939640157463
# Expected=-19.11073872197516, Observed=-14.672203033363449
# Expected=-15.074039905703156, Observed=-42.75498787186434
# Expected=-45.48578886737392, Observed=-113.39296967113027
# Expected=-116.0378297260957, Observed=-101.52384784629119
# Expected=-89.07822806496837, Observed=-79.02111841560958
# Expected=-67.1470854773265, Observed=-86.4073689075973
# Expected=-79.76756948533588, Observed=-161.8988184697345
# Expected=-159.76746391033453, Observed=-154.53418178580694
# Expected=-136.74248296181136, Observed=-157.62621207221352
# Expected=-141.68791663783543, Observed=-166.5926886946328
# Expected=-150.86266039380226, Observed=-128.307749998742
# Expected=-107.70210975451478, Observed=-103.14882373801265
# Expected=-88.34612373679202, Observed=-90.11467298694978
# Expected=-79.38080101710104, Observed=-83.94328712152472
# Expected=-75.28533552065545, Observed=-88.53579622390326
# Expected=-81.58837162852673, Observed=-96.65206014126832
# Expected=-89.42597694871056, Observed=-119.885142165504
# Expected=-112.89518978166328, Observed=-119.43373281777474
# Expected=-107.81699638031085, Observed=-119.42845061592239
# Expected=-107.91634443748308, Observed=-129.861261281768
# Expected=-119.171215300053, Observed=-115.53012223942672
# Expected=-101.68720849041614, Observed=-133.92402846057342
# Expected=-124.36381261877447, Observed=-106.12936789806426
# Expected=-90.80523841425303, Observed=-72.04895965157556
# Expected=-59.547281667905914, Observed=-71.63611986978302
# Expected=-65.99334997507324, Observed=-63.15666206056648
# Expected=-56.95391755046536, Observed=-89.6466547128468
# Expected=-87.14620123298351, Observed=-99.13558312503511
# Expected=-92.10833188209604, Observed=-67.56311718753788
# Expected=-56.25855469057649, Observed=-71.22409040602767
# Expected=-66.47008573886541, Observed=-48.83848669249749
# Expected=-41.67336305498105, Observed=2.513673475727383
# Expected=9.139003286239586, Observed=-4.0853426599678615
# Expected=-8.166824158853572, Observed=-92.88747203198032
# Expected=-102.38150173305745, Observed=-159.40079044105616
# Expected=-156.43518175731768, Observed=-191.24261095299275
# Expected=-177.48454115332206, Observed=-223.05790558569575
# Expected=-205.55058044902603, Observed=-220.5799917988449
# Expected=-196.50337449807492, Observed=-195.36267417664226
# Expected=-169.79023063783575, Observed=-215.76064288296325
# Expected=-197.06062078417614, Observed=-147.30928575230783
# Expected=-118.95075982836642, Observed=-104.27240387445943
# Expected=-86.25063437925219, Observed=-103.376119027233
# Expected=-93.9853878352953, Observed=-64.21720486131254
# Expected=-51.897020207696244, Observed=-66.18956251053766
# Expected=-61.9191998659776, Observed=-79.96311073247143
# Expected=-76.3908950980309, Observed=-88.66615394625107
# Expected=-83.02209351837664, Observed=-81.72195169323383
# Expected=-73.7850052134209, Observed=-98.87221597107064
# Expected=-93.70180508544166, Observed=-96.9607934249815
# Expected=-88.20057529556226, Observed=-110.56781914288977
# Expected=-103.29651377142874, Observed=-108.26602547567792
# Expected=-98.07867133617484, Observed=-9.800843482108702
# Expected=7.750360457774349, Observed=-108.01016246456058
# Expected=-117.61136705522026, Observed=-148.68725458983303
# Expected=-142.080275798797, Observed=-112.38443327657069
# Expected=-94.97811764818043, Observed=-123.61720643776344
# Expected=-114.25437161648505, Observed=-115.66672895120986
# Expected=-103.50680336383867, Observed=-106.64289879235041
# Expected=-95.38557382286048, Observed=-93.08808699815509
# Expected=-82.59637949567139, Observed=-94.09994544005511
# Expected=-86.36607034391392, Observed=-140.77486482762072
# Expected=-136.3781174246763, Observed=-167.99150346282644
# Expected=-156.51994126616515, Observed=-26.37670388142983
# Expected=1.0847453869409236, Observed=11.171058557523805
# Expected=13.601590652876638, Observed=-14.792822355913005
# Expected=-21.67593588675618, Observed=39.41354928818256
# Expected=41.61384513458918, Observed=11.02926104871213
# Expected=0.5474603965285425, Observed=-35.214753327071946
# Expected=-43.524243384812664, Observed=-239.32596247563464
# Expected=-256.43336433010643, Observed=-291.7377093614879
# Expected=-271.99775432422456, Observed=-229.8989427659178
# Expected=-194.17221523552632, Observed=-161.89704352418715
# Expected=-133.24541620299368, Observed=-123.53837013113026
# Expected=-105.55147708197102, Observed=-140.50714299301873
# Expected=-132.5021429917786, Observed=-140.4601794870536
# Expected=-129.10651003152344, Observed=-140.5246347391261
# Expected=-129.35079791948786, Observed=-131.31807968258693
# Expected=-119.47526859253006, Observed=-134.36480951893992
# Expected=-124.86421530069138, Observed=-128.2186932949382
# Expected=-117.68358552745075, Observed=-89.02985630258343
# Expected=-76.40957149862682, Observed=-72.20901858238553
# Expected=-66.31672887333545, Observed=-72.20096107267186
# Expected=-69.86094822128358, Observed=-60.1379141395486
# Expected=-56.735181010736696, Observed=-91.26731258970216
# Expected=-93.21951842986755, Observed=-85.61501696710815
# Expected=-80.62488492503417, Observed=-94.38616078694339
# Expected=-91.4141827843589, Observed=-130.28705931761598
# Expected=-128.73298625026743, Observed=-59.14315992683024
# Expected=-43.97730418154103, Observed=-29.708315101228685
# Expected=-26.691177412391557, Observed=-19.207967048400903
# Expected=-21.315904284851314, Observed=-109.51846901517378
# Expected=-121.80814072501636, Observed=-94.87142393715425
# Expected=-87.1521104446675, Observed=-199.00428846059071
# Expected=-203.18621455976898, Observed=-180.39838420773276
# Expected=-161.70404295870972, Observed=-157.40811785467633
# Expected=-140.827760169912, Observed=-137.56515674502245
# Expected=-124.23412160206165, Observed=-125.11742052202936
# Expected=-114.96750411916129, Observed=-194.27299723397667
# Expected=-192.54739308192558, Observed=-136.86408428403007
# Expected=-116.40547248738781, Observed=-129.37815807354073
# Expected=-120.17522394434253, Observed=-44.58528165294793
# Expected=-30.074695216368625, Observed=-57.109578114413914
# Expected=-60.890609445287375, Observed=-84.17742725327976
# Expected=-87.61941362586795, Observed=-69.68304901513773
# Expected=-66.44906613009461, Observed=-96.34947194988446
# Expected=-98.22248691260849, Observed=-128.4631574104956
# Expected=-127.5565567256926, Observed=-253.44877273352623
# Expected=-256.31085903525695, Observed=-194.296923074927
# Expected=-167.02734216927237, Observed=-188.6129521250252
# Expected=-173.14235711619736, Observed=-190.8018476865077
# Expected=-176.8621115740064, Observed=-124.24168476953189
# Expected=-104.85490198658329, Observed=-116.75656783560373
# Expected=-110.35496664660675, Observed=-22.20951101883713
# Expected=-9.962739450216517, Observed=-50.698553551653575
# Expected=-59.684537558302, Observed=35.551207214724805
# Expected=39.05988694146182, Observed=62.867275045924224
# Expected=51.69476755075701, Observed=38.67441039051476
# Expected=20.278076035212727, Observed=89.32087986101352
# Expected=80.16947934422032, Observed=118.93579834246744
# Expected=102.7014058837896, Observed=116.52713185768286
# Expected=94.50998607616913, Observed=87.91594756530112
# Expected=64.50776533663763, Observed=90.40054207229065
# Expected=73.51490769811981, Observed=58.68773629283751
# Expected=38.77613741117956, Observed=43.43135352154848
# Expected=28.781321250376863, Observed=73.9567828131849
# Expected=66.80289130636169, Observed=62.3836449812911
# Expected=48.593668771837734, Observed=79.17410426331286
# Expected=68.78871170176272, Observed=132.22578954290628
# Expected=122.39630808945108, Observed=153.47634040061945
# Expected=135.07442523748642, Observed=156.39840621933462
# Expected=134.2048883344075, Observed=95.01878616047769
# Expected=67.85755187759068, Observed=80.01959320768815
# Expected=63.62104632736778, Observed=-1.7772747772909243
# Expected=-21.094967670050252, Observed=-13.327803397619054
# Expected=-17.720443362130286, Observed=-34.192542610112454
# Expected=-37.82738381935354, Observed=-82.75897211525697
# Expected=-85.7991703227292, Observed=-125.0032891485122
# Expected=-121.70542404937379, Observed=-115.13349478418039
# Expected=-102.98370443280706, Observed=-113.65651030410459
# Expected=-103.31961457736031, Observed=-120.62206713879584
# Expected=-111.09000212174047, Observed=-136.2501270348959
# Expected=-126.50172523415273, Observed=-121.46655471592507
# Expected=-107.67117498531103, Observed=-91.86928747684235
# Expected=-78.80267836276549, Observed=-78.99116974704562
# Expected=-70.73856380889015, Observed=-71.61183618148559
# Expected=-65.3284094057319, Observed=-88.32997145317754
# Expected=-84.66068546206652, Observed=-36.47806578033103
# Expected=-25.91647739144183, Observed=-36.59850825826198
# Expected=-36.03819548837775, Observed=-33.34267694261516
# Expected=-32.53299470939399, Observed=-41.495125032541154
# Expected=-41.88657680750042, Observed=-30.85629399073325
# Expected=-28.92694562743933, Observed=-27.359998773179896
# Expected=-27.233079737773938, Observed=-40.76581267014092
# Expected=-42.25522047258078, Observed=-4.586393075905005
# Expected=-0.9588765045275025, Observed=46.565264457054276
# Expected=46.864288160712405, Observed=-31.3870353783428
# Expected=-46.36302727042415, Observed=-67.49983828190707
# Expected=-70.06392675922609, Observed=-114.81232501654857
# Expected=-115.16411359695823, Observed=-112.88634627841105
# Expected=-102.59917314053403, Observed=-153.66815238976366
# Expected=-148.28483431954055, Observed=-133.30912931546615
# Expected=-118.5191071431014, Observed=-91.21656905513638
# Expected=-77.17754750836627, Observed=-141.55447037347045
# Expected=-139.7248195656439, Observed=-126.2378043602294
# Expected=-113.48971817076585, Observed=-65.41629567959056
# Expected=-50.698545211437356, Observed=-49.065168137603486
# Expected=-44.49227357692299, Observed=-53.423444192339076
# Expected=-51.68142536167967, Observed=-31.00387645593763
# Expected=-26.878576907690384, Observed=-34.25175216007513
# Expected=-34.646789332896574, Observed=-97.94030799540919
# Expected=-104.14111090730725, Observed=-146.4655342395403
# Expected=-144.08108839733623, Observed=-171.42048791888774
# Expected=-161.40511379130646, Observed=-169.34699428085216
# Expected=-154.38109987760643, Observed=-160.30124705135535
# Expected=-145.18368472490508, Observed=-181.32633021886446
# Expected=-169.6064838978292, Observed=-206.01387157848617
# Expected=-192.29557362620284, Observed=-189.1474391515332
# Expected=-169.433634804721, Observed=-166.00501626130773
# Expected=-147.99227384635836, Observed=-141.9712639704277
# Expected=-126.80373165137027, Observed=-142.29636898920486
# Expected=-131.99797682267973, Observed=-118.56783220160285
# Expected=-106.47460101980894, Observed=-131.1411842938681
# Expected=-124.76394828308901, Observed=-79.47976326477615
# Expected=-66.75626548324581, Observed=-41.18287031088039
# Expected=-35.69852033550908, Observed=-26.163172953536414
# Expected=-27.047937718065374, Observed=-23.31628958011736
# Expected=-26.909751497564592, Observed=-7.964022966790368
# Expected=-10.866371137721313, Observed=-71.37531223203966
# Expected=-82.18864695111046, Observed=-70.05118099518884
# Expected=-68.25694728560228, Observed=-66.23818615185749
# Expected=-64.43041096821972, Observed=-86.06676292981312
# Expected=-86.52264679996725, Observed=-65.0700535368488
# Expected=-60.05580177271099, Observed=-121.7557093281793
# Expected=-125.15439575368546, Observed=-68.90440512940066
# Expected=-57.308505570068185, Observed=-78.58900871142231
# Expected=-78.03193532619399, Observed=-34.836438672087894
# Expected=-29.175761578332605, Observed=-86.68197804601526
# Expected=-93.29512874735549, Observed=-70.38067364480753
# Expected=-65.79039949786736, Observed=-41.437938722320546
# Expected=-37.91175198672047, Observed=-74.49389325748628
# Expected=-78.93454963422822, Observed=-22.422802190166493
# Expected=-16.758266889546924, Observed=-44.68732134744519
# Expected=-50.578389508531785, Observed=-173.75802710487366
# Expected=-184.61524935070832, Observed=-184.37142356349696
# Expected=-171.13875049783323, Observed=-139.22153467183014
# Expected=-120.86350301998344, Observed=-99.02654357926382
# Expected=-86.62032530349279, Observed=-13.38077205211667
# Expected=-2.623106019442517, Observed=-101.80319534047251
# Expected=-113.80706901648954, Observed=-211.45746077575262
# Expected=-214.41251971797288, Observed=-215.84897754566066
# Expected=-197.83317238102362, Observed=-121.63945410786589
# Expected=-96.1398666293426, Observed=-145.99409520148512
# Expected=-140.71049790763826, Observed=-168.56191519272477
# Expected=-160.22859515800894, Observed=-105.61405768773248
# Expected=-88.60629890118585, Observed=-82.47896082307082
# Expected=-76.11018677886344, Observed=-81.28844797665204
# Expected=-79.34416044617697, Observed=-167.0785421092863
# Expected=-171.3589122980975, Observed=-137.1421370220466
# Expected=-122.82108301823237, Observed=-162.9440781943873
# Expected=-156.25462471557572, Observed=-163.28074583625113

# %%
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.plot(forecasts, color='red')
plt.show()

# %%
# Ensuring that data is one-dimensional
test = test.ravel()
forecasts = np.array(forecasts).ravel()

# %%
# Getting the high, low, and close values ​​from the test set for the CCI
test_size_A = len(test)

high_test_A = base_A['High'].tail(test_size_A)
low_test_A = base_A['Low'].tail(test_size_A)
close_test_A = base_A['Close/Last'].tail(test_size_A)

# %%
print(test.shape)
print(forecasts.shape)
# Out:
# (368,)
# (368,)

# %%
# Inverse CCI formula
def cci_inverse_A(cci_values_A, high_test_A, low_test_A, close_test_A):
    tp = (high_test_A + low_test_A + close_test_A) / 3
    sma_tp = tp.rolling(window=20).mean()
    mean_deviation = (tp - sma_tp).abs().rolling(window=20).mean()
    tp_inverted = cci_values_A * 0.015 * mean_deviation + sma_tp
    return tp_inverted

# %%
test_inverted = cci_inverse_A(test, high_test_A, low_test_A, close_test_A)
forecasts_inverted = cci_inverse_A(forecasts, high_test_A, low_test_A, close_test_A)

# %%
test_inverted = test_inverted.dropna()
forecasts_inverted = pd.Series(forecasts_inverted).dropna()

# %%
min_length_R = min(len(test_R), len(forecasts_inverted))
test_R = test_R[:min_length_R]
forecasts_inverted = forecasts_inverted[:min_length_R]

# %%
# RMSE
rmse = sqrt(mean_squared_error(test_R, forecasts_inverted))
print(f'RMSE: {rmse}')

# R2 Score
r2 = r2_score(test_R, forecasts_inverted)
print(f'R2 Score: {r2}')
# Out:
# RMSE: 1.6677318650792545
# R2 Score: 0.7178966542690057

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(test_R)), test_R, label='Real')
plt.plot(range(len(forecasts_inverted)), forecasts_inverted, label='Prediction', color = 'red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
