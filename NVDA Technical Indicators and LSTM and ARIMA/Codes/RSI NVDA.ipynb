# %% [markdown]
# #LSTM and ARIMA with RSI (Relative Strength Index) technical indicator

# %% [markdown]
# **Students:** Gabriel Sposito and Thomas Frentzel

# %% [markdown]
# **LSTM**

# %%
# !pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=1462f6f56605233588042575bf93dc4710c237e3feafd2a1b3e107a091d53072
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator

# %%
base = pd.read_csv('NVDA 5Y.csv')
base.head()
# Out:
#          Date Close/Last     Volume     Open     High        Low
# 0  10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1  10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2  10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3  10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4  10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14

# %%
# Removing nule results
base.dropna()
# Out:
#             Date Close/Last     Volume     Open     High        Low
# 0     10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1     10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2     10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3     10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4     10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14
# ...          ...        ...        ...      ...      ...        ...
# 1253  10/15/2019    $4.9093  667985200   $4.754  $4.9823      $4.74
# 1254  10/14/2019    $4.6633  210335760   $4.641  $4.6843    $4.6096
# 1255  10/11/2019    $4.6498  450866800  $4.6603  $4.7335    $4.6413
# 1256  10/10/2019    $4.5758  327515560  $4.5155   $4.627    $4.5103
# 1257  10/09/2019    $4.5178  307883280   $4.508  $4.5675     $4.479
#
# [1258 rows x 6 columns]

# %%
# Removing $
base['Close/Last'] = base['Close/Last'].str.replace('$', '')
base['Open'] = base['Open'].str.replace('$', '')
base['High'] = base['High'].str.replace('$', '')
base['Low'] = base['Low'].str.replace('$', '')

# Converting str to float
base['Close/Last'] = base['Close/Last'].astype(float)
base['Open'] = base['Open'].astype(float)
base['High'] = base['High'].astype(float)
base['Low'] = base['Low'].astype(float)

# %%
cci = CCIIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'], window=20, constant=0.015)
base['CCI'] = cci.cci()

sma_tp = base['High'] + base['Low'] + base['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base['Close/Last'], window=14)
base['RSI'] = rsi.rsi()

macd = MACD(close=base['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base['MACD'] = macd.macd()
base['MACD_Signal'] = macd.macd_signal()
base['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'])
base['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base['Close/Last'], window=20, window_dev=2)
base['Bollinger_High'] = bollinger.bollinger_hband()
base['Bollinger_Low'] = bollinger.bollinger_lband()
base['Bollinger_Middle'] = bollinger.bollinger_mavg()
base['Bollinger_Width'] = bollinger.bollinger_wband()

base.dropna()
# Out:
#             Date  Close/Last     Volume      Open      High       Low  \
# 33    08/21/2024    128.5000  257883600  127.3150  129.3500  126.6600
# 34    08/20/2024    127.2500  300087400  128.4000  129.8800  125.8900
# 35    08/19/2024    130.0000  318333600  124.2800  130.0000  123.4200
# 36    08/16/2024    124.5800  302589900  121.9400  125.0000  121.1800
# 37    08/15/2024    122.8600  318086700  118.7600  123.2400  117.4700
# ...          ...         ...        ...       ...       ...       ...
# 1253  10/15/2019      4.9093  667985200    4.7540    4.9823    4.7400
# 1254  10/14/2019      4.6633  210335760    4.6410    4.6843    4.6096
# 1255  10/11/2019      4.6498  450866800    4.6603    4.7335    4.6413
# 1256  10/10/2019      4.5758  327515560    4.5155    4.6270    4.5103
# 1257  10/09/2019      4.5178  307883280    4.5080    4.5675    4.4790
#
#              CCI        RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    109.563550  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34     93.439821  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35     85.454132  60.187685  2.240879     0.121107   2.119773     118.873314
# 36     43.621331  53.180795  2.132257     0.523337   1.608920     120.359716
# 37     20.947193  51.145899  1.885647     0.795799   1.089848     131.260000
# ...          ...        ...       ...          ...        ...            ...
# 1253  -81.288448  39.738294 -0.131057    -0.128466  -0.002591       4.993934
# 1254 -167.078542  30.794457 -0.143643    -0.131501  -0.012142       4.980500
# 1255 -137.142137  30.390224 -0.152944    -0.135790  -0.017154       4.982300
# 1256 -162.944078  28.204663 -0.164391    -0.141510  -0.022881       4.937576
# 1257 -163.280746  26.590538 -0.176113    -0.148431  -0.027683       4.877757
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33        133.280229     100.584771        116.932500        27.960967
# 34        134.480982     100.772018        117.626500        28.657628
# 35        136.004529     100.689471        118.347000        29.840264
# 36        136.582416     100.891584        118.737000        30.058729
# 37        136.860746     100.989254        118.925000        30.163121
# ...              ...            ...               ...              ...
# 1253        5.343533       4.736087          5.039810        12.052969
# 1254        5.347782       4.677718          5.012750        13.367186
# 1255        5.344708       4.626322          4.985515        14.409444
# 1256        5.339425       4.568335          4.953880        15.565376
# 1257        5.333658       4.506802          4.920230        16.805226
#
# [1225 rows x 16 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(base['RSI'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base['Close/Last'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base = base.replace([np.inf, -np.inf], np.nan)
base = base.dropna()

# %%
# Normalizing the data of real values
scaler_real_value = MinMaxScaler(feature_range=(0, 1))
scaled_data_real_value = scaler_real_value.fit_transform(np.array(base['Close/Last']).reshape(-1, 1))

# %%
window_size_real_value = 10
forecasters_real_value = []
real_value_of_prices = []
for i in range(window_size_real_value, len(base)):
    forecasters_real_value.append(scaled_data_real_value[i - window_size_real_value:i, 0])
    real_value_of_prices.append(scaled_data_real_value[i, 0])

forecasters_real_value, real_value_of_prices = np.array(forecasters_real_value), np.array(real_value_of_prices)
forecasters_real_value = np.reshape(forecasters_real_value, (forecasters_real_value.shape[0], forecasters_real_value.shape[1], 1))

# %%
#dividindo a coluna close/last em 70% treino e 30% teste com trai_test_split
Xtrain_real_lstm, Xtest_real_lstm, ytrain_real_lstm, ytest_real_lstm = train_test_split(forecasters_real_value, real_value_of_prices,
                                                                                        test_size = 0.3, shuffle = False)

# %%
#plotando grafico dos valores de teste
plt.figure(figsize=(16,8))
plt.plot(ytest_real_lstm)
plt.show()

# %%
# Normalizing the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(base['RSI']).reshape(-1, 1))

# %%
window_size = 10
forecasters = []
real_value = []
for i in range(window_size, len(base)):
    forecasters.append(scaled_data[i - window_size:i, 0])
    real_value.append(scaled_data[i, 0])

forecasters, real_value = np.array(forecasters), np.array(real_value)
forecasters = np.reshape(forecasters, (forecasters.shape[0], forecasters.shape[1], 1))

# %%
# Separating data between training and testing
X_train, X_test, y_train, y_test = train_test_split(forecasters, real_value, test_size=0.3, shuffle=False)

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test)
plt.show()

# %%
# LSTM model

lstm = Sequential()
lstm.add(LSTM(units=50, return_sequences=True, input_shape=(forecasters.shape[1], 1)))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50, return_sequences=True))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50))
lstm.add(Dropout(0.3))
lstm.add(Dense(units=1))
lstm.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = lstm.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - loss: 0.1107 - mean_absolute_error: 0.2735 - val_loss: 0.0160 - val_mean_absolute_error: 0.1006
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0272 - mean_absolute_error: 0.1336 - val_loss: 0.0107 - val_mean_absolute_error: 0.0834
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0219 - mean_absolute_error: 0.1222 - val_loss: 0.0108 - val_mean_absolute_error: 0.0840
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0207 - mean_absolute_error: 0.1179 - val_loss: 0.0104 - val_mean_absolute_error: 0.0823
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0200 - mean_absolute_error: 0.1139 - val_loss: 0.0100 - val_mean_absolute_error: 0.0811
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.1108 - val_loss: 0.0097 - val_mean_absolute_error: 0.0797
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0182 - mean_absolute_error: 0.1103 - val_loss: 0.0102 - val_mean_absolute_error: 0.0817
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0171 - mean_absolute_error: 0.1067 - val_loss: 0.0094 - val_mean_absolute_error: 0.0788
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0168 - mean_absolute_error: 0.1051 - val_loss: 0.0121 - val_mean_absolute_error: 0.0894
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0175 - mean_absolute_error: 0.1070 - val_loss: 0.0086 - val_mean_absolute_error: 0.0754
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0143 - mean_absolute_error: 0.0973 - val_loss: 0.0084 - val_mean_absolute_error: 0.0745
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0148 - mean_absolute_error: 0.0974 - val_loss: 0.0087 - val_mean_absolute_error: 0.0757
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0152 - mean_absolute_error: 0.0997 - val_loss: 0.0077 - val_mean_absolute_error: 0.0705
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0122 - mean_absolute_error: 0.0903 - val_loss: 0.0079 - val_mean_absolute_error: 0.0703
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0140 - mean_absolute_error: 0.0964 - val_loss: 0.0073 - val_mean_absolute_error: 0.0681
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0125 - mean_absolute_error: 0.0906 - val_loss: 0.0084 - val_mean_absolute_error: 0.0746
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0128 - mean_absolute_error: 0.0888 - val_loss: 0.0071 - val_mean_absolute_error: 0.0670
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0111 - mean_absolute_error: 0.0840 - val_loss: 0.0071 - val_mean_absolute_error: 0.0667
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0110 - mean_absolute_error: 0.0847 - val_loss: 0.0070 - val_mean_absolute_error: 0.0662
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0109 - mean_absolute_error: 0.0837 - val_loss: 0.0077 - val_mean_absolute_error: 0.0692
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0110 - mean_absolute_error: 0.0825 - val_loss: 0.0075 - val_mean_absolute_error: 0.0702
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0107 - mean_absolute_error: 0.0813 - val_loss: 0.0066 - val_mean_absolute_error: 0.0651
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0096 - mean_absolute_error: 0.0786 - val_loss: 0.0065 - val_mean_absolute_error: 0.0639
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0103 - mean_absolute_error: 0.0814 - val_loss: 0.0068 - val_mean_absolute_error: 0.0666
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0102 - mean_absolute_error: 0.0801 - val_loss: 0.0064 - val_mean_absolute_error: 0.0632
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0108 - mean_absolute_error: 0.0830 - val_loss: 0.0062 - val_mean_absolute_error: 0.0627
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0097 - mean_absolute_error: 0.0772 - val_loss: 0.0064 - val_mean_absolute_error: 0.0648
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0092 - mean_absolute_error: 0.0758 - val_loss: 0.0061 - val_mean_absolute_error: 0.0630
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0098 - mean_absolute_error: 0.0796 - val_loss: 0.0064 - val_mean_absolute_error: 0.0629
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0097 - mean_absolute_error: 0.0780 - val_loss: 0.0060 - val_mean_absolute_error: 0.0628
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0098 - mean_absolute_error: 0.0782 - val_loss: 0.0058 - val_mean_absolute_error: 0.0608
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0099 - mean_absolute_error: 0.0782 - val_loss: 0.0077 - val_mean_absolute_error: 0.0696
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0104 - mean_absolute_error: 0.0808 - val_loss: 0.0056 - val_mean_absolute_error: 0.0609
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0092 - mean_absolute_error: 0.0761 - val_loss: 0.0059 - val_mean_absolute_error: 0.0605
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0085 - mean_absolute_error: 0.0730 - val_loss: 0.0055 - val_mean_absolute_error: 0.0598
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0086 - mean_absolute_error: 0.0734 - val_loss: 0.0056 - val_mean_absolute_error: 0.0607
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0082 - mean_absolute_error: 0.0728 - val_loss: 0.0053 - val_mean_absolute_error: 0.0587
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0077 - mean_absolute_error: 0.0687 - val_loss: 0.0052 - val_mean_absolute_error: 0.0582
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0083 - mean_absolute_error: 0.0721 - val_loss: 0.0060 - val_mean_absolute_error: 0.0608
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0075 - mean_absolute_error: 0.0691 - val_loss: 0.0054 - val_mean_absolute_error: 0.0579
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0089 - mean_absolute_error: 0.0755 - val_loss: 0.0049 - val_mean_absolute_error: 0.0565
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0083 - mean_absolute_error: 0.0732 - val_loss: 0.0049 - val_mean_absolute_error: 0.0564
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0085 - mean_absolute_error: 0.0738 - val_loss: 0.0049 - val_mean_absolute_error: 0.0563
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0076 - mean_absolute_error: 0.0693 - val_loss: 0.0050 - val_mean_absolute_error: 0.0556
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0071 - mean_absolute_error: 0.0673 - val_loss: 0.0050 - val_mean_absolute_error: 0.0555
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0077 - mean_absolute_error: 0.0693 - val_loss: 0.0048 - val_mean_absolute_error: 0.0548
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0071 - mean_absolute_error: 0.0679 - val_loss: 0.0048 - val_mean_absolute_error: 0.0545
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0068 - mean_absolute_error: 0.0652 - val_loss: 0.0046 - val_mean_absolute_error: 0.0542
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0077 - mean_absolute_error: 0.0700 - val_loss: 0.0048 - val_mean_absolute_error: 0.0554
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0072 - mean_absolute_error: 0.0677 - val_loss: 0.0046 - val_mean_absolute_error: 0.0530
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0066 - mean_absolute_error: 0.0640 - val_loss: 0.0044 - val_mean_absolute_error: 0.0525
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0076 - mean_absolute_error: 0.0697 - val_loss: 0.0046 - val_mean_absolute_error: 0.0527
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0076 - mean_absolute_error: 0.0712 - val_loss: 0.0051 - val_mean_absolute_error: 0.0578
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0077 - mean_absolute_error: 0.0701 - val_loss: 0.0047 - val_mean_absolute_error: 0.0532
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0066 - mean_absolute_error: 0.0653 - val_loss: 0.0046 - val_mean_absolute_error: 0.0545
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0065 - mean_absolute_error: 0.0634 - val_loss: 0.0044 - val_mean_absolute_error: 0.0517
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0066 - mean_absolute_error: 0.0638 - val_loss: 0.0043 - val_mean_absolute_error: 0.0516
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0066 - mean_absolute_error: 0.0647 - val_loss: 0.0042 - val_mean_absolute_error: 0.0515
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0064 - mean_absolute_error: 0.0638 - val_loss: 0.0046 - val_mean_absolute_error: 0.0522
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0061 - mean_absolute_error: 0.0629 - val_loss: 0.0042 - val_mean_absolute_error: 0.0513
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0061 - mean_absolute_error: 0.0619 - val_loss: 0.0045 - val_mean_absolute_error: 0.0516
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0068 - mean_absolute_error: 0.0661 - val_loss: 0.0042 - val_mean_absolute_error: 0.0508
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0071 - mean_absolute_error: 0.0667 - val_loss: 0.0042 - val_mean_absolute_error: 0.0512
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0063 - mean_absolute_error: 0.0638 - val_loss: 0.0042 - val_mean_absolute_error: 0.0505
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0059 - mean_absolute_error: 0.0615 - val_loss: 0.0042 - val_mean_absolute_error: 0.0504
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0065 - mean_absolute_error: 0.0642 - val_loss: 0.0042 - val_mean_absolute_error: 0.0511
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0578 - val_loss: 0.0043 - val_mean_absolute_error: 0.0504
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0063 - mean_absolute_error: 0.0627 - val_loss: 0.0046 - val_mean_absolute_error: 0.0546
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0042 - val_mean_absolute_error: 0.0507
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0056 - mean_absolute_error: 0.0596 - val_loss: 0.0045 - val_mean_absolute_error: 0.0514
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0631 - val_loss: 0.0041 - val_mean_absolute_error: 0.0501
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0059 - mean_absolute_error: 0.0581 - val_loss: 0.0044 - val_mean_absolute_error: 0.0534
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0059 - mean_absolute_error: 0.0598 - val_loss: 0.0048 - val_mean_absolute_error: 0.0571
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0058 - mean_absolute_error: 0.0621 - val_loss: 0.0043 - val_mean_absolute_error: 0.0520
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0060 - mean_absolute_error: 0.0615 - val_loss: 0.0045 - val_mean_absolute_error: 0.0511
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0619 - val_loss: 0.0042 - val_mean_absolute_error: 0.0500
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0072 - mean_absolute_error: 0.0659 - val_loss: 0.0045 - val_mean_absolute_error: 0.0546
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0064 - mean_absolute_error: 0.0639 - val_loss: 0.0041 - val_mean_absolute_error: 0.0509
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0062 - mean_absolute_error: 0.0621 - val_loss: 0.0041 - val_mean_absolute_error: 0.0497
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0058 - mean_absolute_error: 0.0602 - val_loss: 0.0042 - val_mean_absolute_error: 0.0510
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0600 - val_loss: 0.0041 - val_mean_absolute_error: 0.0500
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0060 - mean_absolute_error: 0.0623 - val_loss: 0.0041 - val_mean_absolute_error: 0.0502
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0598 - val_loss: 0.0043 - val_mean_absolute_error: 0.0502
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - mean_absolute_error: 0.0571 - val_loss: 0.0041 - val_mean_absolute_error: 0.0511
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0060 - mean_absolute_error: 0.0605 - val_loss: 0.0041 - val_mean_absolute_error: 0.0503
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0586 - val_loss: 0.0048 - val_mean_absolute_error: 0.0527
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065 - mean_absolute_error: 0.0625 - val_loss: 0.0042 - val_mean_absolute_error: 0.0516
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0054 - mean_absolute_error: 0.0588 - val_loss: 0.0042 - val_mean_absolute_error: 0.0495
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0594 - val_loss: 0.0041 - val_mean_absolute_error: 0.0501
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0042 - val_mean_absolute_error: 0.0496
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0058 - mean_absolute_error: 0.0602 - val_loss: 0.0043 - val_mean_absolute_error: 0.0531
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0060 - mean_absolute_error: 0.0608 - val_loss: 0.0042 - val_mean_absolute_error: 0.0513
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0586 - val_loss: 0.0042 - val_mean_absolute_error: 0.0496
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0055 - mean_absolute_error: 0.0573 - val_loss: 0.0041 - val_mean_absolute_error: 0.0506
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0586 - val_loss: 0.0050 - val_mean_absolute_error: 0.0535
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0603 - val_loss: 0.0043 - val_mean_absolute_error: 0.0523
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0582 - val_loss: 0.0041 - val_mean_absolute_error: 0.0503
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0059 - mean_absolute_error: 0.0605 - val_loss: 0.0041 - val_mean_absolute_error: 0.0506
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0057 - mean_absolute_error: 0.0607 - val_loss: 0.0042 - val_mean_absolute_error: 0.0521
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - mean_absolute_error: 0.0600 - val_loss: 0.0043 - val_mean_absolute_error: 0.0521

# %%
test_predictions = lstm.predict(X_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step

# %%
# Transforming test values ​​back to original values
y_orig_test = scaler.inverse_transform(y_test.reshape(-1, 1))

#escalonando valores de teste
ytest_real_lstm = scaler_real_value.inverse_transform(ytest_real_lstm.reshape(-1, 1))

# %%
test_predictions = test_predictions.ravel()
y_orig_test = y_orig_test.ravel()
ytest_real_lstm = ytest_real_lstm.ravel()

# %%
test_size_L = len(y_test)

rsi_test = base['RSI'].tail(test_size_L)
close_test = base['Close/Last'].tail(test_size_L)

# %%
# Inverse RSI formula
def inverse_rsi(predictions, close_prices, rsi_values, period=14):
    inverted_values = []

    for rsi, pred, close in zip(rsi_values, predictions, close_prices):
        # Calculates real RS from RSI
        rs_real = (100 - rsi) / rsi

        # Reverse predicted RSI to get RS (relative strength) estimate
        rs_pred = (100 - pred) / pred

        # Calculates the price change based on the difference between actual and forecast RS considering that RS = average gains / average losses
        gain = (rs_pred - rs_real) * close / (1 + rs_real)
        inverted_price = close + gain

        inverted_values.append(inverted_price)

    return np.array(inverted_values)

# %%
# Inverting the values ​​test_predictions and y_orig_teste by the inverse RSI formula
test_predictions_inverted = inverse_rsi(test_predictions, close_test, rsi_test)
y_orig_test_inverted = inverse_rsi(y_orig_test, close_test, rsi_test)

min_length = min(len(ytest_real_lstm), len(test_predictions_inverted))
ytest_real_lstm = ytest_real_lstm[:min_length]
test_predictions_inverted = test_predictions_inverted[:min_length]

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(ytest_real_lstm)), ytest_real_lstm, label='Real')
plt.plot(range(len(test_predictions_inverted)), test_predictions_inverted, label='Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# R2 Score
r2 = r2_score(y_orig_test_inverted, test_predictions_inverted)
print(f'R2 Score: {r2}')

# RMSE
rmse = np.sqrt(np.mean((y_orig_test_inverted - test_predictions_inverted) ** 2))
print(f'RMSE: {rmse}')
# Out:
# R2 Score: 0.9035076281381231
# RMSE: 1.0456590223256266

# %% [markdown]
# **ARIMA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator
from math import sqrt

# %%
base_A = pd.read_csv('NVDA 5Y.csv')
base_A.head()
# Out:
#          Date Close/Last     Volume     Open     High        Low
# 0  10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1  10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2  10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3  10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4  10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14

# %%
base_A.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
# Removing $
base_A['Close/Last'] = base_A['Close/Last'].str.replace('$', '')
base_A['Open'] = base_A['Open'].str.replace('$', '')
base_A['High'] = base_A['High'].str.replace('$', '')
base_A['Low'] = base_A['Low'].str.replace('$', '')

# Converting str to float
base_A['Close/Last'] = base_A['Close/Last'].astype(float)
base_A['Open'] = base_A['Open'].astype(float)
base_A['High'] = base_A['High'].astype(float)
base_A['Low'] = base_A['Low'].astype(float)

# %%
cci = CCIIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'], window=20, constant=0.015)
base_A['CCI'] = cci.cci()

sma_tp = base_A['High'] + base_A['Low'] + base_A['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base_A['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base_A['Close/Last'], window=14)
base_A['RSI'] = rsi.rsi()

macd = MACD(close=base_A['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base_A['MACD'] = macd.macd()
base_A['MACD_Signal'] = macd.macd_signal()
base_A['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'])
base_A['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base_A['Close/Last'], window=20, window_dev=2)
base_A['Bollinger_High'] = bollinger.bollinger_hband()
base_A['Bollinger_Low'] = bollinger.bollinger_lband()
base_A['Bollinger_Middle'] = bollinger.bollinger_mavg()
base_A['Bollinger_Width'] = bollinger.bollinger_wband()

base_A.dropna()
# Out:
#             Date  Close/Last     Volume      Open      High       Low  \
# 33    08/21/2024    128.5000  257883600  127.3150  129.3500  126.6600
# 34    08/20/2024    127.2500  300087400  128.4000  129.8800  125.8900
# 35    08/19/2024    130.0000  318333600  124.2800  130.0000  123.4200
# 36    08/16/2024    124.5800  302589900  121.9400  125.0000  121.1800
# 37    08/15/2024    122.8600  318086700  118.7600  123.2400  117.4700
# ...          ...         ...        ...       ...       ...       ...
# 1253  10/15/2019      4.9093  667985200    4.7540    4.9823    4.7400
# 1254  10/14/2019      4.6633  210335760    4.6410    4.6843    4.6096
# 1255  10/11/2019      4.6498  450866800    4.6603    4.7335    4.6413
# 1256  10/10/2019      4.5758  327515560    4.5155    4.6270    4.5103
# 1257  10/09/2019      4.5178  307883280    4.5080    4.5675    4.4790
#
#              CCI        RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    109.563550  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34     93.439821  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35     85.454132  60.187685  2.240879     0.121107   2.119773     118.873314
# 36     43.621331  53.180795  2.132257     0.523337   1.608920     120.359716
# 37     20.947193  51.145899  1.885647     0.795799   1.089848     131.260000
# ...          ...        ...       ...          ...        ...            ...
# 1253  -81.288448  39.738294 -0.131057    -0.128466  -0.002591       4.993934
# 1254 -167.078542  30.794457 -0.143643    -0.131501  -0.012142       4.980500
# 1255 -137.142137  30.390224 -0.152944    -0.135790  -0.017154       4.982300
# 1256 -162.944078  28.204663 -0.164391    -0.141510  -0.022881       4.937576
# 1257 -163.280746  26.590538 -0.176113    -0.148431  -0.027683       4.877757
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33        133.280229     100.584771        116.932500        27.960967
# 34        134.480982     100.772018        117.626500        28.657628
# 35        136.004529     100.689471        118.347000        29.840264
# 36        136.582416     100.891584        118.737000        30.058729
# 37        136.860746     100.989254        118.925000        30.163121
# ...              ...            ...               ...              ...
# 1253        5.343533       4.736087          5.039810        12.052969
# 1254        5.347782       4.677718          5.012750        13.367186
# 1255        5.344708       4.626322          4.985515        14.409444
# 1256        5.339425       4.568335          4.953880        15.565376
# 1257        5.333658       4.506802          4.920230        16.805226
#
# [1225 rows x 16 columns]

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base_A = base_A.replace([np.inf, -np.inf], np.nan)
base_A = base_A.dropna()

# %%
base_A.head()
# Out:
#           Date  Close/Last     Volume     Open    High     Low         CCI  \
# 33  08/21/2024      128.50  257883600  127.315  129.35  126.66  109.563550
# 34  08/20/2024      127.25  300087400  128.400  129.88  125.89   93.439821
# 35  08/19/2024      130.00  318333600  124.280  130.00  123.42   85.454132
# 36  08/16/2024      124.58  302589900  121.940  125.00  121.18   43.621331
# 37  08/15/2024      122.86  318086700  118.760  123.24  117.47   20.947193
#
#           RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35  60.187685  2.240879     0.121107   2.119773     118.873314
# 36  53.180795  2.132257     0.523337   1.608920     120.359716
# 37  51.145899  1.885647     0.795799   1.089848     131.260000
#
#     Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33      133.280229     100.584771          116.9325        27.960967
# 34      134.480982     100.772018          117.6265        28.657628
# 35      136.004529     100.689471          118.3470        29.840264
# 36      136.582416     100.891584          118.7370        30.058729
# 37      136.860746     100.989254          118.9250        30.163121

# %%
#Plotting RSI
plt.figure(figsize=(16,8))
plt.plot(base_A['RSI'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base_A['Close/Last'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
X_R = base_A['Close/Last'].values
size_R = int(len(X_R) * 0.70)
train_R, test_R = X_R[0:size_R], X_R[size_R:len(X_R)]
history_R = [x_r for x_r in train_R]
forecasts_R = list()

# %%
#Test Grafic
plt.figure(figsize=(16, 8))
plt.plot(test_R)
plt.show()

# %%
# Addfuller for RSI
result = adfuller(base_A['RSI'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -6.092389374129575
# p-value: 1.0290431249968746e-07

# %%
plot_acf(base_A['RSI'], lags=40)
plt.show()

# %%
plot_pacf(base_A['RSI'], lags=40)
plt.show()

# %%
X = base_A['RSI'].values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
forecasts = list()

# %%
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.show()

# %%
# ARIMA
for t in range(len(test)):
    model = ARIMA(history, order=(2, 1, 1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    forecasts.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'Expected={yhat}, Observed={obs}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Expected=29.516630795320122, Observed=27.24487797641096
# Expected=28.11399084877108, Observed=29.219845142066617
# Expected=30.00067420084741, Observed=36.58372653061709
# Expected=37.012742601570594, Observed=38.44572526767188
# Expected=38.75335241816828, Observed=35.16749183710627
# Expected=35.62181150936235, Observed=34.035723733325156
# Expected=34.55781158998765, Observed=43.80927896661123
# Expected=43.86791881449406, Observed=43.25164301927485
# Expected=43.29132544189613, Observed=42.097510314348256
# Expected=42.196095778872404, Observed=38.39772232255798
# Expected=38.684560739001256, Observed=40.699343046107764
# Expected=40.88671033612709, Observed=35.27755896315382
# Expected=35.72525977416565, Observed=36.184016770055095
# Expected=36.60339663151284, Observed=28.516565876372297
# Expected=28.83689813232792, Observed=41.10418023117506
# Expected=41.20779133240176, Observed=40.301361531947464
# Expected=39.82302043275099, Observed=45.738870018543594
# Expected=45.34056168627159, Observed=52.22606655907169
# Expected=51.587618845433525, Observed=56.29891215903188
# Expected=55.583440178974385, Observed=54.82831007696382
# Expected=54.317800662961034, Observed=50.300774930274905
# Expected=50.19709286130693, Observed=60.56681860464846
# Expected=60.38790498943267, Observed=56.78218007915681
# Expected=56.41290652347977, Observed=58.456420140248774
# Expected=58.34486446539175, Observed=62.61924205342049
# Expected=62.35408177786768, Observed=61.485695320012766
# Expected=61.231474936953965, Observed=62.06966340494816
# Expected=61.960911120682674, Observed=65.2008085126472
# Expected=65.01273042855364, Observed=60.521674824596964
# Expected=60.477454628606615, Observed=62.778575016069404
# Expected=62.84596326831654, Observed=56.892477660406314
# Expected=57.06983301866347, Observed=51.532941989649295
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Expected=40.6528798041994, Observed=41.72819321820873
# Expected=41.79000967721273, Observed=40.392528618767635
# Expected=40.6665231403438, Observed=40.007308617806345
# Expected=40.2582040777281, Observed=40.85769973971911
# Expected=40.9957460536973, Observed=40.084089326052315
# Expected=40.348854315783, Observed=43.31646575764107
# Expected=43.1868259739499, Observed=44.75592034651751
# Expected=44.62607598073871, Observed=35.990588316515286
# Expected=36.900862385216534, Observed=34.542349069488466
# Expected=35.17907872998046, Observed=37.93023515169518
# Expected=38.12509450657947, Observed=37.84500633763924
# Expected=38.213032600682254, Observed=44.36139779935465
# Expected=44.008644169737785, Observed=41.62781356398821
# Expected=41.8936361107399, Observed=33.94557303348185
# Expected=34.920778202823406, Observed=32.46044304697212
# Expected=33.22560282888577, Observed=33.38358470208
# Expected=33.977541027626025, Observed=34.12204436855593
# Expected=34.67901711948817, Observed=29.25697827340582
# Expected=30.37419915784192, Observed=36.02424288074373
# Expected=36.16860283514154, Observed=35.946282382284295
# Expected=36.42860628052348, Observed=39.73829363694578
# Expected=39.79850892988357, Observed=30.794457000505062
# Expected=32.03943523040794, Observed=30.390223885978855
# Expected=31.224761521451278, Observed=28.204663106978643
# Expected=29.25997553702256, Observed=26.590538428666704

# %%
# Test and forecast set
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.plot(forecasts, color='red')
plt.show()

# %%
# Ensuring that data is one-dimensional
test = test.ravel()
forecasts = np.array(forecasts).ravel()

# %%
# Getting the high, low and close values ​​from the test set for the RSI
test_size_A = len(test)

rsi_test_A = base_A['RSI'].tail(test_size_A)
close_test_A = base_A['Close/Last'].tail(test_size_A)

# %%
print(test.shape)
print(forecasts.shape)
# Out:
# (368,)
# (368,)

# %%
# Inverse RSI formula
def inverse_rsi_A(predictions_A, close_prices_A, rsi_values_A, period=14):
    inverted_values = []

    for rsi, pred, close in zip(rsi_values_A, predictions_A, close_prices_A):
        # Calculates real RS from RSI
        rs_real = (100 - rsi) / rsi

        # Reverse predicted RSI to get RS (relative strength) estimate
        rs_pred = (100 - pred) / pred

        # Calculates the price change based on the difference between actual and forecast RS considering that RS = average gains / average losses
        gain = (rs_pred - rs_real) * close / (1 + rs_real)
        inverted_price = close + gain

        inverted_values.append(inverted_price)

    return np.array(inverted_values)

# %%
test_inverted = inverse_rsi_A(test, close_test_A, rsi_test_A)
forecasts_inverted = inverse_rsi_A(forecasts, close_test_A, rsi_test_A)

min_length_R = min(len(test_R), len(forecasts_inverted))
test_R = test_R[:min_length_R]
forecasts_inverted = forecasts_inverted[:min_length_R]

# %%
# RMSE
rmse = sqrt(mean_squared_error(test_R, forecasts_inverted))
print(f'RMSE: {rmse}')

# R2 Score
r2 = r2_score(test_R, forecasts_inverted)
print(f'R2 Score: {r2}')
# Out:
# RMSE: 1.1073774335702007
# R2 Score: 0.8916238970599423

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(test_R)), test_R, label='Real')
plt.plot(range(len(forecasts_inverted)), forecasts_inverted, label='Prediction', color = 'red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
