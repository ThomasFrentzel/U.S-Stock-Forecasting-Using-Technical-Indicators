# %% [markdown]
# #LSTM and ARIMA with MACD (Moving Average Convergence Divergence) Technical Indicator

# %% [markdown]
# **Authors:** Gabriel Sposito and Thomas Frentzel

# %% [markdown]
# **LSTM**

# %%
# !pip install ta

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator

# %%
base = pd.read_csv('AMD 5Y.csv')
base.head()
# Out:
#          Date Close/Last    Volume      Open       High        Low
# 0  10/08/2024    $172.80  34730150   $171.75    $173.60    $170.00
# 1  10/07/2024    $170.97  38379930   $171.08    $172.41    $168.21
# 2  10/04/2024    $170.90  44640300  $166.533    $171.21    $164.42
# 3  10/03/2024    $162.85  29598790   $159.71  $166.7894    $159.40
# 4  10/02/2024    $159.78  24630430   $159.31    $163.10  $158.6689

# %%
# Removing nule results
base.dropna()
# Out:
#             Date Close/Last    Volume      Open       High        Low
# 0     10/08/2024    $172.80  34730150   $171.75    $173.60    $170.00
# 1     10/07/2024    $170.97  38379930   $171.08    $172.41    $168.21
# 2     10/04/2024    $170.90  44640300  $166.533    $171.21    $164.42
# 3     10/03/2024    $162.85  29598790   $159.71  $166.7894    $159.40
# 4     10/02/2024    $159.78  24630430   $159.31    $163.10  $158.6689
# ...          ...        ...       ...       ...        ...        ...
# 1253  10/15/2019     $30.72  42142390    $30.70     $30.92     $30.17
# 1254  10/14/2019     $30.53  44818230    $29.71     $30.61     $29.38
# 1255  10/11/2019     $29.75  66632450    $28.83     $30.20     $28.81
# 1256  10/10/2019     $28.38  41172000    $28.52     $28.89     $28.00
# 1257  10/09/2019     $28.46  36321580    $28.80     $28.95     $28.35
#
# [1258 rows x 6 columns]

# %%
# Removing $
base['Close/Last'] = base['Close/Last'].str.replace('$', '')
base['Open'] = base['Open'].str.replace('$', '')
base['High'] = base['High'].str.replace('$', '')
base['Low'] = base['Low'].str.replace('$', '')

# Converting str to float
base['Close/Last'] = base['Close/Last'].astype(float)
base['Open'] = base['Open'].astype(float)
base['High'] = base['High'].astype(float)
base['Low'] = base['Low'].astype(float)

# %%
cci = CCIIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'], window=20, constant=0.015)
base['CCI'] = cci.cci()

sma_tp = base['High'] + base['Low'] + base['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base['Close/Last'], window=14)
base['RSI'] = rsi.rsi()

macd = MACD(close=base['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base['MACD'] = macd.macd()
base['MACD_Signal'] = macd.macd_signal()
base['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'])
base['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base['Close/Last'], window=20, window_dev=2)
base['Bollinger_High'] = bollinger.bollinger_hband()
base['Bollinger_Low'] = bollinger.bollinger_lband()
base['Bollinger_Middle'] = bollinger.bollinger_mavg()
base['Bollinger_Width'] = bollinger.bollinger_wband()

base.dropna()
# Out:
#             Date  Close/Last    Volume    Open      High     Low         CCI  \
# 33    08/21/2024      157.81  42791250  156.12  158.6500  155.07  128.490106
# 34    08/20/2024      156.40  76851160  156.49  162.0400  154.51  120.837780
# 35    08/19/2024      155.28  60766850  148.43  155.3650  147.72   60.194674
# 36    08/16/2024      148.56  31123930  145.70  149.3693  145.20    2.305252
# 37    08/15/2024      147.36  43582390  143.00  147.9600  141.81  -19.231609
# ...          ...         ...       ...     ...       ...     ...         ...
# 1253  10/15/2019       30.72  42142390   30.70   30.9200   30.17  -99.383285
# 1254  10/14/2019       30.53  44818230   29.71   30.6100   29.38 -105.536352
# 1255  10/11/2019       29.75  66632450   28.83   30.2000   28.81 -117.461809
# 1256  10/10/2019       28.38  41172000   28.52   28.8900   28.00 -148.813340
# 1257  10/09/2019       28.46  36321580   28.80   28.9500   28.35 -133.729404
#
#             RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    56.724050 -1.735664    -4.266283   2.530619     146.212562
# 34    54.942210 -1.096467    -3.632320   2.535853     148.392952
# 35    53.504486 -0.672520    -3.040360   2.367840     162.040000
# 36    45.766121 -0.868773    -2.606043   1.737270     162.040000
# 37    44.527651 -1.108358    -2.306506   1.198148     161.366400
# ...         ...       ...          ...        ...            ...
# 1253  24.075332 -2.154763    -2.139259  -0.015504      31.550800
# 1254  23.449722 -2.121456    -2.135699   0.014243      31.410000
# 1255  21.033342 -2.133407    -2.135240   0.001833      31.004000
# 1256  17.602422 -2.227746    -2.153741  -0.074004      30.610000
# 1257  18.439062 -2.269888    -2.176971  -0.092918      30.200000
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33        159.538951     134.672049          147.1055        16.904128
# 34        160.585017     134.436983          147.5110        17.726158
# 35        161.173218     134.294782          147.7340        18.193805
# 36        160.856405     134.259595          147.5580        18.024648
# 37        160.428964     134.192036          147.3105        17.810630
# ...              ...            ...               ...              ...
# 1253       37.639676      29.249324           33.4445        25.087388
# 1254       37.317478      28.993522           33.1555        25.105806
# 1255       36.981669      28.675331           32.8285        25.302215
# 1256       36.699642      28.167358           32.4335        26.307012
# 1257       36.344227      27.775773           32.0600        26.726306
#
# [1225 rows x 16 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(base['MACD'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base['Close/Last'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base = base.replace([np.inf, -np.inf], np.nan)
base = base.dropna()

# %%
# Normalizing the data of real values
scaler_real_value = MinMaxScaler(feature_range=(0, 1))
scaled_data_real_value = scaler_real_value.fit_transform(np.array(base['Close/Last']).reshape(-1, 1))

# %%
window_size_real_value = 10
forecasters_real_value = []
real_value_of_prices = []
for i in range(window_size_real_value, len(base)):
    forecasters_real_value.append(scaled_data_real_value[i - window_size_real_value:i, 0])
    real_value_of_prices.append(scaled_data_real_value[i, 0])

forecasters_real_value, real_value_of_prices = np.array(forecasters_real_value), np.array(real_value_of_prices)
forecasters_real_value = np.reshape(forecasters_real_value, (forecasters_real_value.shape[0], forecasters_real_value.shape[1], 1))

# %%
#dividindo a coluna close/last em 70% treino e 30% teste com trai_test_split
Xtrain_real_lstm, Xtest_real_lstm, ytrain_real_lstm, ytest_real_lstm = train_test_split(forecasters_real_value, real_value_of_prices,
                                                                                        test_size = 0.3, shuffle = False)

# %%
#plotando grafico dos valores de teste
plt.figure(figsize=(16,8))
plt.plot(ytest_real_lstm)
plt.show()

# %%
# Normalizing the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(base['MACD']).reshape(-1, 1))

# %%
window_size = 10
forecasters = []
real_value = []
for i in range(window_size, len(base)):
    forecasters.append(scaled_data[i - window_size:i, 0])
    real_value.append(scaled_data[i, 0])

forecasters, real_value = np.array(forecasters), np.array(real_value)
forecasters = np.reshape(forecasters, (forecasters.shape[0], forecasters.shape[1], 1))

# %%
# Separating data between training and testing
X_train, X_test, y_train, y_test = train_test_split(forecasters, real_value, test_size=0.3, shuffle=False)

# %%
# Showing test set in graph
plt.figure(figsize=(16, 8))
plt.plot(y_test)
plt.show()

# %%
# LSTM model

lstm = Sequential()
lstm.add(LSTM(units=50, return_sequences=True, input_shape=(forecasters.shape[1], 1)))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50, return_sequences=True))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50))
lstm.add(Dropout(0.3))
lstm.add(Dense(units=1))
lstm.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = lstm.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 0.1076 - mean_absolute_error: 0.2689 - val_loss: 0.0047 - val_mean_absolute_error: 0.0526
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0207 - mean_absolute_error: 0.1131 - val_loss: 0.0040 - val_mean_absolute_error: 0.0479
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0159 - mean_absolute_error: 0.0968 - val_loss: 0.0041 - val_mean_absolute_error: 0.0495
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0145 - mean_absolute_error: 0.0921 - val_loss: 0.0030 - val_mean_absolute_error: 0.0404
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0149 - mean_absolute_error: 0.0953 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0127 - mean_absolute_error: 0.0878 - val_loss: 0.0028 - val_mean_absolute_error: 0.0391
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0111 - mean_absolute_error: 0.0837 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0139 - mean_absolute_error: 0.0915 - val_loss: 0.0029 - val_mean_absolute_error: 0.0412
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0106 - mean_absolute_error: 0.0789 - val_loss: 0.0028 - val_mean_absolute_error: 0.0417
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0110 - mean_absolute_error: 0.0821 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0089 - mean_absolute_error: 0.0747 - val_loss: 0.0022 - val_mean_absolute_error: 0.0373
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0079 - mean_absolute_error: 0.0684 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0075 - mean_absolute_error: 0.0677 - val_loss: 0.0029 - val_mean_absolute_error: 0.0443
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0082 - mean_absolute_error: 0.0689 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0072 - mean_absolute_error: 0.0675 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0066 - mean_absolute_error: 0.0639 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0058 - mean_absolute_error: 0.0600 - val_loss: 9.9981e-04 - val_mean_absolute_error: 0.0241
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - mean_absolute_error: 0.0564 - val_loss: 9.6645e-04 - val_mean_absolute_error: 0.0243
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0059 - mean_absolute_error: 0.0596 - val_loss: 9.0428e-04 - val_mean_absolute_error: 0.0223
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0055 - mean_absolute_error: 0.0564 - val_loss: 8.3694e-04 - val_mean_absolute_error: 0.0220
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0052 - mean_absolute_error: 0.0556 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0059 - mean_absolute_error: 0.0583 - val_loss: 8.0331e-04 - val_mean_absolute_error: 0.0212
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0052 - mean_absolute_error: 0.0557 - val_loss: 8.4029e-04 - val_mean_absolute_error: 0.0217
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0054 - mean_absolute_error: 0.0554 - val_loss: 0.0017 - val_mean_absolute_error: 0.0341
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0059 - mean_absolute_error: 0.0599 - val_loss: 0.0019 - val_mean_absolute_error: 0.0373
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0045 - mean_absolute_error: 0.0521 - val_loss: 7.6784e-04 - val_mean_absolute_error: 0.0216
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0047 - mean_absolute_error: 0.0528 - val_loss: 8.1294e-04 - val_mean_absolute_error: 0.0218
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0054 - mean_absolute_error: 0.0545 - val_loss: 9.5009e-04 - val_mean_absolute_error: 0.0238
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0048 - mean_absolute_error: 0.0523 - val_loss: 7.1270e-04 - val_mean_absolute_error: 0.0208
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0042 - mean_absolute_error: 0.0494 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0043 - mean_absolute_error: 0.0496 - val_loss: 6.4243e-04 - val_mean_absolute_error: 0.0191
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0043 - mean_absolute_error: 0.0494 - val_loss: 5.7232e-04 - val_mean_absolute_error: 0.0181
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0032 - mean_absolute_error: 0.0435 - val_loss: 5.7275e-04 - val_mean_absolute_error: 0.0184
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0039 - mean_absolute_error: 0.0468 - val_loss: 9.4390e-04 - val_mean_absolute_error: 0.0248
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0037 - mean_absolute_error: 0.0462 - val_loss: 5.2196e-04 - val_mean_absolute_error: 0.0173
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0032 - mean_absolute_error: 0.0447 - val_loss: 5.5514e-04 - val_mean_absolute_error: 0.0184
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0029 - mean_absolute_error: 0.0434 - val_loss: 4.9859e-04 - val_mean_absolute_error: 0.0169
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0033 - mean_absolute_error: 0.0435 - val_loss: 4.6795e-04 - val_mean_absolute_error: 0.0164
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0037 - mean_absolute_error: 0.0439 - val_loss: 4.5270e-04 - val_mean_absolute_error: 0.0161
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0031 - mean_absolute_error: 0.0426 - val_loss: 4.4748e-04 - val_mean_absolute_error: 0.0161
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0031 - mean_absolute_error: 0.0428 - val_loss: 4.1263e-04 - val_mean_absolute_error: 0.0153
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0034 - mean_absolute_error: 0.0444 - val_loss: 4.0247e-04 - val_mean_absolute_error: 0.0151
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0032 - mean_absolute_error: 0.0432 - val_loss: 4.0888e-04 - val_mean_absolute_error: 0.0155
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0034 - mean_absolute_error: 0.0442 - val_loss: 3.9353e-04 - val_mean_absolute_error: 0.0152
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0032 - mean_absolute_error: 0.0413 - val_loss: 3.7265e-04 - val_mean_absolute_error: 0.0145
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0031 - mean_absolute_error: 0.0415 - val_loss: 7.5749e-04 - val_mean_absolute_error: 0.0230
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0029 - mean_absolute_error: 0.0414 - val_loss: 3.5272e-04 - val_mean_absolute_error: 0.0141
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0029 - mean_absolute_error: 0.0407 - val_loss: 4.8579e-04 - val_mean_absolute_error: 0.0177
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0030 - mean_absolute_error: 0.0411 - val_loss: 4.2702e-04 - val_mean_absolute_error: 0.0164
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0028 - mean_absolute_error: 0.0396 - val_loss: 6.6512e-04 - val_mean_absolute_error: 0.0215
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0030 - mean_absolute_error: 0.0417 - val_loss: 3.4850e-04 - val_mean_absolute_error: 0.0143
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0033 - mean_absolute_error: 0.0433 - val_loss: 4.2172e-04 - val_mean_absolute_error: 0.0159
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0026 - mean_absolute_error: 0.0392 - val_loss: 3.7340e-04 - val_mean_absolute_error: 0.0147
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0027 - mean_absolute_error: 0.0389 - val_loss: 6.7925e-04 - val_mean_absolute_error: 0.0218
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 3.0147e-04 - val_mean_absolute_error: 0.0128
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 8.3596e-04 - val_mean_absolute_error: 0.0243
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 3.2674e-04 - val_mean_absolute_error: 0.0138
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0025 - mean_absolute_error: 0.0382 - val_loss: 2.9475e-04 - val_mean_absolute_error: 0.0129
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0025 - mean_absolute_error: 0.0372 - val_loss: 3.0986e-04 - val_mean_absolute_error: 0.0132
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0027 - mean_absolute_error: 0.0393 - val_loss: 9.0122e-04 - val_mean_absolute_error: 0.0262
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 2.9582e-04 - val_mean_absolute_error: 0.0132
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0021 - mean_absolute_error: 0.0365 - val_loss: 4.4815e-04 - val_mean_absolute_error: 0.0173
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0023 - mean_absolute_error: 0.0363 - val_loss: 4.1636e-04 - val_mean_absolute_error: 0.0166
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 2.8551e-04 - val_mean_absolute_error: 0.0130
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0022 - mean_absolute_error: 0.0338 - val_loss: 2.8221e-04 - val_mean_absolute_error: 0.0129
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 4.1399e-04 - val_mean_absolute_error: 0.0162
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0023 - mean_absolute_error: 0.0356 - val_loss: 3.7428e-04 - val_mean_absolute_error: 0.0156
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0023 - mean_absolute_error: 0.0361 - val_loss: 5.0176e-04 - val_mean_absolute_error: 0.0185
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0358 - val_loss: 2.5381e-04 - val_mean_absolute_error: 0.0119
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0023 - mean_absolute_error: 0.0361 - val_loss: 2.6142e-04 - val_mean_absolute_error: 0.0121
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0024 - mean_absolute_error: 0.0363 - val_loss: 3.5597e-04 - val_mean_absolute_error: 0.0151
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0354 - val_loss: 3.3922e-04 - val_mean_absolute_error: 0.0146
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 3.1344e-04 - val_mean_absolute_error: 0.0140
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020 - mean_absolute_error: 0.0329 - val_loss: 2.3356e-04 - val_mean_absolute_error: 0.0114
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020 - mean_absolute_error: 0.0336 - val_loss: 2.5971e-04 - val_mean_absolute_error: 0.0122
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0021 - mean_absolute_error: 0.0337 - val_loss: 2.4508e-04 - val_mean_absolute_error: 0.0120
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 2.4477e-04 - val_mean_absolute_error: 0.0121
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020 - mean_absolute_error: 0.0335 - val_loss: 3.2667e-04 - val_mean_absolute_error: 0.0145
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 2.1588e-04 - val_mean_absolute_error: 0.0109
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 2.4108e-04 - val_mean_absolute_error: 0.0119
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0350 - val_loss: 5.3115e-04 - val_mean_absolute_error: 0.0196
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0021 - mean_absolute_error: 0.0356 - val_loss: 2.1630e-04 - val_mean_absolute_error: 0.0110
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 3.8467e-04 - val_mean_absolute_error: 0.0159
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 2.0595e-04 - val_mean_absolute_error: 0.0107
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 2.5191e-04 - val_mean_absolute_error: 0.0124
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 2.6530e-04 - val_mean_absolute_error: 0.0130
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - val_loss: 2.6270e-04 - val_mean_absolute_error: 0.0127
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 2.0838e-04 - val_mean_absolute_error: 0.0111
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0302 - val_loss: 2.4009e-04 - val_mean_absolute_error: 0.0120
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 4.1508e-04 - val_mean_absolute_error: 0.0172
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0016 - mean_absolute_error: 0.0309 - val_loss: 1.8463e-04 - val_mean_absolute_error: 0.0102
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 2.0437e-04 - val_mean_absolute_error: 0.0109
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0017 - mean_absolute_error: 0.0303 - val_loss: 1.7960e-04 - val_mean_absolute_error: 0.0100
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - val_loss: 1.7935e-04 - val_mean_absolute_error: 0.0101
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 5.0839e-04 - val_mean_absolute_error: 0.0193
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 7.8456e-04 - val_mean_absolute_error: 0.0252
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0016 - mean_absolute_error: 0.0309 - val_loss: 2.0684e-04 - val_mean_absolute_error: 0.0113
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0015 - mean_absolute_error: 0.0301 - val_loss: 1.6531e-04 - val_mean_absolute_error: 0.0096
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0289 - val_loss: 2.7343e-04 - val_mean_absolute_error: 0.0133

# %%
test_predictions = lstm.predict(X_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step

# %%
# Transforming test values ​​back to original values
y_orig_test = scaler.inverse_transform(y_test.reshape(-1, 1))

#escalonando valores de teste
ytest_real_lstm = scaler_real_value.inverse_transform(ytest_real_lstm.reshape(-1, 1))

# %%
test_predictions = test_predictions.ravel()  # Converts to 1D
y_orig_test = y_orig_test.ravel()
ytest_real_lstm = ytest_real_lstm.ravel()

# %%
test_size_L = len(y_test)

close_test_L = base['Close/Last'].tail(test_size_L)

# %%
# Inverse MACD formula
def MACD_inverse(macd_values, close_values, short_window=12, long_window=26):
    original_prices = []
    for i in range(len(macd_values)):
        if i < long_window:
            original_prices.append(close_values[i])
            continue
        # Calculate moving averages
        short_ma = np.mean(close_values[max(0, i-short_window):i+1]) # Average of the last 'short_window' prices
        long_ma = np.mean(close_values[max(0, i-long_window):i+1])  # Average of the last 'long_window' prices
        # Estimate adjusted price
        estimated_price = close_values[i]
        price_adjustment = (macd_values[i] / 100) * (short_ma - long_ma)  # Estimate adjusted price
        estimated_price += price_adjustment
        original_prices.append(estimated_price)
    return np.array(original_prices)

# Making sure the data is in array format
close_test_L = close_test_L.values if isinstance(close_test_L, pd.Series) else close_test_L

# %%
# Inverting the values ​​test_predictions and y_orig_teste by the inverse MACD formula
test_predictions_inverted = MACD_inverse(test_predictions, close_test_L)
y_orig_test_inverted = MACD_inverse(y_orig_test, close_test_L)

min_length = min(len(ytest_real_lstm), len(test_predictions_inverted))
ytest_real_lstm = ytest_real_lstm[:min_length]
test_predictions_inverted = test_predictions_inverted[:min_length]

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(ytest_real_lstm)), ytest_real_lstm, label='Real')
plt.plot(range(len(test_predictions_inverted)), test_predictions_inverted, label='Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# R2 Score
r2 = r2_score(ytest_real_lstm, test_predictions_inverted)
print(f'R2 Score: {r2}')

# RMSE
rmse = np.sqrt(np.mean((ytest_real_lstm - test_predictions_inverted) ** 2))
print(f'RMSE: {rmse}')
# Out:
# R2 Score: 0.9999418655418603
# RMSE: 0.1529853777350829

# %% [markdown]
# **ARIMA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator
from math import sqrt

# %%
base_A = pd.read_csv('AMD 5Y.csv')
base_A.head()
# Out:
#          Date Close/Last    Volume      Open       High        Low
# 0  10/08/2024    $172.80  34730150   $171.75    $173.60    $170.00
# 1  10/07/2024    $170.97  38379930   $171.08    $172.41    $168.21
# 2  10/04/2024    $170.90  44640300  $166.533    $171.21    $164.42
# 3  10/03/2024    $162.85  29598790   $159.71  $166.7894    $159.40
# 4  10/02/2024    $159.78  24630430   $159.31    $163.10  $158.6689

# %%
base_A.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
# Removing $
base_A['Close/Last'] = base_A['Close/Last'].str.replace('$', '')
base_A['Open'] = base_A['Open'].str.replace('$', '')
base_A['High'] = base_A['High'].str.replace('$', '')
base_A['Low'] = base_A['Low'].str.replace('$', '')

# Converting str to float
base_A['Close/Last'] = base_A['Close/Last'].astype(float)
base_A['Open'] = base_A['Open'].astype(float)
base_A['High'] = base_A['High'].astype(float)
base_A['Low'] = base_A['Low'].astype(float)

# %%
cci = CCIIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'], window=20, constant=0.015)
base_A['CCI'] = cci.cci()

sma_tp = base_A['High'] + base_A['Low'] + base_A['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base_A['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base_A['Close/Last'], window=14)
base_A['RSI'] = rsi.rsi()

macd = MACD(close=base_A['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base_A['MACD'] = macd.macd()
base_A['MACD_Signal'] = macd.macd_signal()
base_A['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'])
base_A['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base_A['Close/Last'], window=20, window_dev=2)
base_A['Bollinger_High'] = bollinger.bollinger_hband()
base_A['Bollinger_Low'] = bollinger.bollinger_lband()
base_A['Bollinger_Middle'] = bollinger.bollinger_mavg()
base_A['Bollinger_Width'] = bollinger.bollinger_wband()

base_A.dropna()
# Out:
#             Date  Close/Last    Volume    Open      High     Low         CCI  \
# 33    08/21/2024      157.81  42791250  156.12  158.6500  155.07  128.490106
# 34    08/20/2024      156.40  76851160  156.49  162.0400  154.51  120.837780
# 35    08/19/2024      155.28  60766850  148.43  155.3650  147.72   60.194674
# 36    08/16/2024      148.56  31123930  145.70  149.3693  145.20    2.305252
# 37    08/15/2024      147.36  43582390  143.00  147.9600  141.81  -19.231609
# ...          ...         ...       ...     ...       ...     ...         ...
# 1253  10/15/2019       30.72  42142390   30.70   30.9200   30.17  -99.383285
# 1254  10/14/2019       30.53  44818230   29.71   30.6100   29.38 -105.536352
# 1255  10/11/2019       29.75  66632450   28.83   30.2000   28.81 -117.461809
# 1256  10/10/2019       28.38  41172000   28.52   28.8900   28.00 -148.813340
# 1257  10/09/2019       28.46  36321580   28.80   28.9500   28.35 -133.729404
#
#             RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    56.724050 -1.735664    -4.266283   2.530619     146.212562
# 34    54.942210 -1.096467    -3.632320   2.535853     148.392952
# 35    53.504486 -0.672520    -3.040360   2.367840     162.040000
# 36    45.766121 -0.868773    -2.606043   1.737270     162.040000
# 37    44.527651 -1.108358    -2.306506   1.198148     161.366400
# ...         ...       ...          ...        ...            ...
# 1253  24.075332 -2.154763    -2.139259  -0.015504      31.550800
# 1254  23.449722 -2.121456    -2.135699   0.014243      31.410000
# 1255  21.033342 -2.133407    -2.135240   0.001833      31.004000
# 1256  17.602422 -2.227746    -2.153741  -0.074004      30.610000
# 1257  18.439062 -2.269888    -2.176971  -0.092918      30.200000
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33        159.538951     134.672049          147.1055        16.904128
# 34        160.585017     134.436983          147.5110        17.726158
# 35        161.173218     134.294782          147.7340        18.193805
# 36        160.856405     134.259595          147.5580        18.024648
# 37        160.428964     134.192036          147.3105        17.810630
# ...              ...            ...               ...              ...
# 1253       37.639676      29.249324           33.4445        25.087388
# 1254       37.317478      28.993522           33.1555        25.105806
# 1255       36.981669      28.675331           32.8285        25.302215
# 1256       36.699642      28.167358           32.4335        26.307012
# 1257       36.344227      27.775773           32.0600        26.726306
#
# [1225 rows x 16 columns]

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base_A = base_A.replace([np.inf, -np.inf], np.nan)
base_A = base_A.dropna()

# %%
base_A.head()
# Out:
#           Date  Close/Last    Volume    Open      High     Low         CCI  \
# 33  08/21/2024      157.81  42791250  156.12  158.6500  155.07  128.490106
# 34  08/20/2024      156.40  76851160  156.49  162.0400  154.51  120.837780
# 35  08/19/2024      155.28  60766850  148.43  155.3650  147.72   60.194674
# 36  08/16/2024      148.56  31123930  145.70  149.3693  145.20    2.305252
# 37  08/15/2024      147.36  43582390  143.00  147.9600  141.81  -19.231609
#
#           RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33  56.724050 -1.735664    -4.266283   2.530619     146.212562
# 34  54.942210 -1.096467    -3.632320   2.535853     148.392952
# 35  53.504486 -0.672520    -3.040360   2.367840     162.040000
# 36  45.766121 -0.868773    -2.606043   1.737270     162.040000
# 37  44.527651 -1.108358    -2.306506   1.198148     161.366400
#
#     Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33      159.538951     134.672049          147.1055        16.904128
# 34      160.585017     134.436983          147.5110        17.726158
# 35      161.173218     134.294782          147.7340        18.193805
# 36      160.856405     134.259595          147.5580        18.024648
# 37      160.428964     134.192036          147.3105        17.810630

# %%
# Plotting MACD
plt.figure(figsize=(16,8))
plt.plot(base_A['MACD'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base_A['Close/Last'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
X_R = base_A['Close/Last'].values
size_R = int(len(X_R) * 0.70)
train_R, test_R = X_R[0:size_R], X_R[size_R:len(X_R)]
history_R = [x_r for x_r in train_R]
forecasts_R = list()

# %%
#Test Grafic
plt.figure(figsize=(16, 8))
plt.plot(test_R)
plt.show()

# %%
#Addfuller for MACD
result = adfuller(base_A['MACD'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -6.009417114549255
# p-value: 1.5865878008302872e-07

# %%
plot_acf(base_A['MACD'], lags=40)
plt.show()

# %%
plot_pacf(base_A['MACD'], lags=40)
plt.show()

# %%
X = base_A['MACD'].values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
forecasts = list()

# %%
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.show()

# %%
# ARIMA
for t in range(len(test)):
    model = ARIMA(history, order=(2, 1, 1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    forecasts.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'Expected={yhat}, Observed={obs}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Expected=-0.7861180065758477, Observed=-0.8656587173465624
# Expected=-1.0144592317851615, Observed=-0.9916053611947149
# Expected=-1.0953512617699928, Observed=-0.9274142090962982
# Expected=-0.8700273864357482, Observed=-0.7133907798557289
# Expected=-0.5514684632098182, Observed=-0.6364961754096186
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Expected=-0.5736717020785224, Observed=-0.6439833522634189
# Expected=-0.6534760469129981, Observed=-0.28273845262165764
# Expected=0.006734809233469308, Observed=0.013082918352608885
# Expected=0.23569973316002998, Observed=0.22475968571590954
# Expected=0.3960253714973526, Observed=0.2723724272602084
# Expected=0.30175903682946814, Observed=0.3209308723189963
# Expected=0.3658279063129996, Observed=0.05936349027311394
# Expected=-0.15462714397882044, Observed=-0.06567492574887979
# Expected=-0.15229216366954673, Observed=-0.5274494690624039
# Expected=-0.9008246187974023, Observed=-0.5194671372532156
# Expected=-0.49663535251650354, Observed=-0.5687178215935376
# Expected=-0.622487473388114, Observed=-0.35273225722663426
# Expected=-0.16873671543949953, Observed=0.08136164371296672
# Expected=0.40662384187501066, Observed=0.6008214049196425
# Expected=1.0178144869050947, Observed=0.8509870707662373
# Expected=1.0326362165382117, Observed=0.8705643067341953
# Expected=0.8958739205322681, Observed=1.236551436831789
# Expected=1.5155125488555576, Observed=1.333703160562564
# Expected=1.412237356008374, Observed=1.4448766972683131
# Expected=1.5288770369912528, Observed=1.8513530955731738
# Expected=2.17301103619487, Observed=2.073733714238557
# Expected=2.240233166555189, Observed=2.3280349543411774
# Expected=2.5322826160908574, Observed=2.6219970660530123
# Expected=2.845604246408768, Observed=3.006702457667103
# Expected=3.31202533056185, Observed=3.185298391750308
# Expected=3.3170580856445953, Observed=3.2641949396303147
# Expected=3.331143306514652, Observed=3.173937876691511
# Expected=3.096916234507436, Observed=3.1117257860506555
# Expected=3.06966791072721, Observed=2.7427365322887454
# Expected=2.446587586930006, Observed=2.417599806038936
# Expected=2.172830402068071, Observed=2.139300663751598
# Expected=1.9155361806278115, Observed=1.9742594478426838
# Expected=1.8532042184892958, Observed=1.7267284730098709
# Expected=1.526486353171191, Observed=1.3519765300723492
# Expected=1.0654832043568336, Observed=1.1929318279979952
# Expected=1.0664234814993843, Observed=1.160028636025217
# Expected=1.1381022855194147, Observed=1.5892921906217623
# Expected=1.925059638793314, Observed=1.8612303921931783
# Expected=2.069907487467369, Observed=1.9461821980717104
# Expected=2.013093547834854, Observed=1.8900483457193076
# Expected=1.8441333404408413, Observed=1.6027634375147954
# Expected=1.3786608413972936, Observed=1.4152580144199192
# Expected=1.2709034586541923, Observed=1.153306380776698
# Expected=0.9471323769188608, Observed=1.140742492528858
# Expected=1.1358422477007462, Observed=1.1968734348699712
# Expected=1.236946147186692, Observed=1.5123962707797318
# Expected=1.7641178130393462, Observed=1.893533577879623
# Expected=2.1854077999939605, Observed=1.9575752449478614
# Expected=2.0080863429316547, Observed=2.031709596697084
# Expected=2.0888843705979516, Observed=1.681339534999779
# Expected=1.4043860293013477, Observed=1.5823163865474612
# Expected=1.512011079952804, Observed=1.4492091746654836
# Expected=1.3393318095642957, Observed=1.2813421662147562
# Expected=1.156210840030762, Observed=1.1814880465885267
# Expected=1.0997080176476655, Observed=0.9565711375185231
# Expected=0.783975695458939, Observed=0.8476297285603209
# Expected=0.7621558147313238, Observed=0.7693693115297151
# Expected=0.7095519376946294, Observed=0.6785456877988452
# Expected=0.6068330820563472, Observed=0.7280879120803689
# Expected=0.7692133846524524, Observed=0.7641897925051353
# Expected=0.78975946411772, Observed=0.9983529205586876
# Expected=1.1849598128731853, Observed=1.24382713290197
# Expected=1.4307761198388502, Observed=1.422773286357227
# Expected=1.5647449504354958, Observed=1.5682977850887596
# Expected=1.6785539324658447, Observed=1.4777736996494895
# Expected=1.4072989852920033, Observed=1.1403229352779647
# Expected=0.87926333204285, Observed=0.8637410209096714
# Expected=0.6518750597731512, Observed=0.49121968035433383
# Expected=0.1974397033738869, Observed=0.4402560126217594
# Expected=0.4079979536962711, Observed=0.4870479423170764
# Expected=0.5179746149416847, Observed=0.5157647198012398
# Expected=0.5427934551233359, Observed=0.39438026090932965
# Expected=0.29410258391556554, Observed=0.4088581890035954
# Expected=0.42692006871862187, Observed=0.3269949339321272
# Expected=0.25634381171414555, Observed=0.2615237804267423
# Expected=0.2170355390220757, Observed=-0.22910488719629996
# Expected=-0.6208110160680366, Observed=-0.6491802833431564
# Expected=-0.9658753839533787, Observed=-1.1017273283773932
# Expected=-1.4628735391281107, Observed=-1.4245863827104586
# Expected=-1.666272886008214, Observed=-1.714751324051619
# Expected=-1.9485833184161083, Observed=-1.8507523313810026
# Expected=-1.94782606105029, Observed=-2.1755308718085047
# Expected=-2.43755680158683, Observed=-2.339781513205452
# Expected=-2.4578023871081585, Observed=-2.412288066855993
# Expected=-2.4766248148313363, Observed=-2.625080516959912
# Expected=-2.7846547299349016, Observed=-2.729176248329537
# Expected=-2.814473030429194, Observed=-2.824303374065508
# Expected=-2.894307674770755, Observed=-3.129097522444809
# Expected=-3.371654868084649, Observed=-2.9230063563893367
# Expected=-2.7534045937179306, Observed=-2.508057364677626
# Expected=-2.1921322163966344, Observed=-2.3841166177276705
# Expected=-2.2845976158848824, Observed=-2.3914665553853496
# Expected=-2.4013009321870937, Observed=-2.750484693944685
# Expected=-3.0291526669671387, Observed=-3.1503936663892347
# Expected=-3.461747197094693, Observed=-3.3807452127045963
# Expected=-3.557480128333833, Observed=-3.3049152821801187
# Expected=-3.2449068948543354, Observed=-3.337072284963739
# Expected=-3.364108430811418, Observed=-3.1264024462903564
# Expected=-2.95861963480981, Observed=-2.6584827442380856
# Expected=-2.296202702525156, Observed=-2.2831213509579555
# Expected=-1.9912905260490008, Observed=-2.1656373949583383
# Expected=-2.077270855804817, Observed=-2.0664617896029824
# Expected=-1.9870423875336267, Observed=-1.7769485741296762
# Expected=-1.5521706258523633, Observed=-1.4947721395095073
# Expected=-1.2755217020241243, Observed=-1.16332596264742
# Expected=-0.9052640655211035, Observed=-0.8935795168136451
# Expected=-0.6850922824306748, Observed=-0.5859026203135187
# Expected=-0.3453553324073284, Observed=-0.2528121444765077
# Expected=0.005120178840159362, Observed=-0.06793713184664796
# Expected=0.07503276514327112, Observed=-0.017246599081417457
# Expected=0.021329798464789308, Observed=0.2946875402541025
# Expected=0.5406970732962854, Observed=0.5500810962548286
# Expected=0.7447742806674251, Observed=0.5676107358992226
# Expected=0.5820583153928989, Observed=0.7080956588582126
# Expected=0.8178663303766479, Observed=0.46308418073368784
# Expected=0.26773099537452694, Observed=0.5099488724511332
# Expected=0.5535757809299232, Observed=0.3119089714040939
# Expected=0.1564653752419678, Observed=0.13564512902929948
# Expected=0.0015604081602180186, Observed=-0.18667719908803804
# Expected=-0.4456560614105886, Observed=-0.5507567758285319
# Expected=-0.8261467116305238, Observed=-1.0080184752596608
# Expected=-1.3707967401214163, Observed=-1.441736120395035
# Expected=-1.7719514035949449, Observed=-1.5281902740436237
# Expected=-1.5983339841800484, Observed=-1.559364436884593
# Expected=-1.5803394684294074, Observed=-1.8061320637613392
# Expected=-2.00284629937598, Observed=-1.8496550527529365
# Expected=-1.881221819791038, Observed=-1.853900641817532
# Expected=-1.8578851576272042, Observed=-1.6550172641124163
# Expected=-1.493764188561442, Observed=-1.5625016005074173
# Expected=-1.497718031098486, Observed=-1.596655976879461
# Expected=-1.617972360680521, Observed=-1.394621303360367
# Expected=-1.2402034912173796, Observed=-0.9867067152373039
# Expected=-0.6656853676892551, Observed=-0.9127370896111273
# Expected=-0.8622396867733604, Observed=-0.5795388121021716
# Expected=-0.3176854438403654, Observed=-0.2696023973917079
# Expected=-0.030537214180318628, Observed=0.5889472425938749
# Expected=1.2605413890873096, Observed=1.4112417212994757
# Expected=2.0489366625355405, Observed=1.930916977022676
# Expected=2.3418009885952906, Observed=1.8956663428796077
# Expected=1.8579117218544259, Observed=1.7068441498287399
# Expected=1.5683934421483008, Observed=1.716549335901945
# Expected=1.7184365185627124, Observed=1.730916084695437
# Expected=1.747107593554254, Observed=1.461591844181001
# Expected=1.2457338626513188, Observed=1.2921601247559522
# Expected=1.167440138563991, Observed=1.0617260411636096
# Expected=0.8764124144225265, Observed=0.7350699808999366
# Expected=0.4863277512656866, Observed=0.5162360877486236
# Expected=0.342934494986245, Observed=0.39952878014860005
# Expected=0.3127799415651494, Observed=0.21419366701299225
# Expected=0.06632270164293452, Observed=0.10962406365018751
# Expected=0.03261375027836509, Observed=0.08787153607364928
# Expected=0.06803101508911666, Observed=-0.3872664446324876
# Expected=-0.7575078405267451, Observed=-0.32753390593065035
# Expected=-0.275825950170282, Observed=-0.06879720004253898
# Expected=0.12838492049867767, Observed=0.283076825368866
# Expected=0.5598394595571994, Observed=0.44385474470408326
# Expected=0.5636029814600252, Observed=0.5432237157535837
# Expected=0.6242274177480835, Observed=0.026966086624213403
# Expected=-0.3812616405244768, Observed=-0.3969618688090293
# Expected=-0.7177620277487831, Observed=-0.6631508724241542
# Expected=-0.8756596714329569, Observed=-1.0324653240038089
# Expected=-1.3140329997575337, Observed=-1.986515503173024
# Expected=-2.735857668288041, Observed=-2.6028623329702896
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Expected=-3.0720710836768386, Observed=-3.0217909052277463
# Expected=-3.354443579963671, Observed=-4.099734477164759
# Expected=-4.935355878221297, Observed=-4.720462523814376
# Expected=-5.200474593978182, Observed=-5.535101733881007
# Expected=-6.171325933742878, Observed=-6.073578588105519
# Expected=-6.4894780429354215, Observed=-6.619296025596441
# Expected=-7.044683872749273, Observed=-6.980991499122425
# Expected=-7.260940489889812, Observed=-7.151311411439103
# Expected=-7.283385967392489, Observed=-7.252715201300433
# Expected=-7.331335908059328, Observed=-7.339653040065869
# Expected=-7.4072375232705445, Observed=-7.141445899040896
# Expected=-6.986061570633042, Observed=-6.795084795399774
# Expected=-6.5257818245424, Observed=-6.7514105997219716
# Expected=-6.719107284912299, Observed=-6.680139812798082
# Expected=-6.623925701393694, Observed=-6.510681050247491
# Expected=-6.378905369153935, Observed=-6.388276822605313
# Expected=-6.293489872024755, Observed=-6.200429899836024
# Expected=-6.054014007368193, Observed=-5.980203052653977
# Expected=-5.8091329583024205, Observed=-5.925379134746059
# Expected=-5.883641623007147, Observed=-5.829259208923659
# Expected=-5.753997315359413, Observed=-5.541538364374212
# Expected=-5.317233939598063, Observed=-5.216269459221529
# Expected=-4.963648945074213, Observed=-4.774349155079442
# Expected=-4.430130932534715, Observed=-4.3122822597535375
# Expected=-3.953167350899358, Observed=-3.94340042142408
# Expected=-3.656956900719468, Observed=-3.6246080931440403
# Expected=-3.3767677988931513, Observed=-3.2928521881594577
# Expected=-3.0337584726756264, Observed=-3.0025835766967788
# Expected=-2.77820613189397, Observed=-2.723397814705258
# Expected=-2.505098416635053, Observed=-2.567757712692469
# Expected=-2.448829457530058, Observed=-2.4700025591190027
# Expected=-2.3925339642956835, Observed=-1.9975162985230455
# Expected=-1.6281314446725434, Observed=-1.6883317205800878
# Expected=-1.4509596967718452, Observed=-1.6996733564301323
# Expected=-1.7095107615532597, Observed=-1.6788193861538971
# Expected=-1.6619702824607714, Observed=-1.6808418380895702
# Expected=-1.682827961043904, Observed=-1.655294279485446
# Expected=-1.635089428123464, Observed=-1.5517992489040324
# Expected=-1.4710336179906591, Observed=-1.4458495896290842
# Expected=-1.3635938903680436, Observed=-1.332802425358075
# Expected=-1.2448133046118308, Observed=-1.393374562463599
# Expected=-1.4415178559358308, Observed=-1.3451803728743243
# Expected=-1.3066376748246078, Observed=-1.25619426567048
# Expected=-1.1872636872730762, Observed=-1.0142114834945914
# Expected=-0.8250937535637577, Observed=-0.854547349499299
# Expected=-0.7313091492126996, Observed=-0.580912516887615
# Expected=-0.36713123391837005, Observed=-0.4332964797486838
# Expected=-0.31962708908473214, Observed=-0.38290446797603295
# Expected=-0.34375209222236575, Observed=-0.3701710745020037
# Expected=-0.3604650700684848, Observed=-0.33124695056078934
# Expected=-0.3007551442817234, Observed=-0.48284489390530183
# Expected=-0.6018373061970315, Observed=-0.4700758193871195
# Expected=-0.45880864518685877, Observed=-0.29676585138128786
# Expected=-0.16178591670591558, Observed=-0.36101854480826745
# Expected=-0.41238256207747764, Observed=-0.506162181597972
# Expected=-0.6187746279940984, Observed=-0.5973583394064548
# Expected=-0.6680125829411112, Observed=-0.6596076557588972
# Expected=-0.7079201767609185, Observed=-0.6713459217813593
# Expected=-0.6802084330119801, Observed=-0.8866810769638462
# Expected=-1.055307285303156, Observed=-0.8450584084946939
# Expected=-0.8108082936059426, Observed=-0.7015072191414333
# Expected=-0.5902863988002136, Observed=-0.43346560675193757
# Expected=-0.22432482192283543, Observed=-0.1403450773100019
# Expected=0.08724551016125187, Observed=0.06617778851840939
# Expected=0.22630601854007598, Observed=0.20489310746069123
# Expected=0.3124890352197278, Observed=0.31283367805693274
# Expected=0.39664453429794866, Observed=0.15452120569721473
# Expected=0.03001378375857297, Observed=0.35180321503708
# Expected=0.5074893169168888, Observed=0.4728440689069089
# Expected=0.5654503279753511, Observed=0.5902083382475851
# Expected=0.6820037784826108, Observed=0.5190811038193672
# Expected=0.462656106890208, Observed=0.45265285913834674
# Expected=0.40159331535295467, Observed=0.07715890266018732
# Expected=-0.2162185863100221, Observed=-0.4221273470325002
# Expected=-0.8100305427007262, Observed=-0.7757889119252681
# Expected=-1.050006751870422, Observed=-1.1421529424033636
# Expected=-1.4272974055729097, Observed=-1.4193651834627943
# Expected=-1.634273348514071, Observed=-2.0136555126864195
# Expected=-2.4775859642957507, Observed=-2.304753001249807
# Expected=-2.5292258258121123, Observed=-2.572766668913438
# Expected=-2.7818789019865013, Observed=-2.608244423705024
# Expected=-2.6346943894388133, Observed=-2.416459252402639
# Expected=-2.2670237995088356, Observed=-2.3407704799873557
# Expected=-2.2825814924923753, Observed=-2.181404399263272
# Expected=-2.0569200471663214, Observed=-2.2606314938610623
# Expected=-2.3233667265701614, Observed=-2.1701042147697436
# Expected=-2.0986988348514997, Observed=-2.439803876851819
# Expected=-2.6507090120243744, Observed=-2.7852403200574187
# Expected=-3.053279306776681, Observed=-3.0073886408588635
# Expected=-3.1798504583360776, Observed=-3.203004691163599
# Expected=-3.355035994985488, Observed=-3.099592711303629
# Expected=-3.0182757134106355, Observed=-3.236126428378533
# Expected=-3.3432313519194197, Observed=-2.89220126166083
# Expected=-2.595610962552483, Observed=-2.9798701337576645
# Expected=-3.047936279332934, Observed=-2.480922724332018
# Expected=-2.097809966656929, Observed=-2.0872639537070015
# Expected=-1.779912627842658, Observed=-1.92337444448561
# Expected=-1.7938931355224992, Observed=-1.3486647213693033
# Expected=-0.9051285641557616, Observed=-0.9213147705360711
# Expected=-0.5872285456087964, Observed=-0.4164529598201696
# Expected=-0.02391896015125622, Observed=-0.2841942424807016
# Expected=-0.17746915943485964, Observed=-0.12069588282749066
# Expected=0.006398691797460249, Observed=-0.14917214369375387
# Expected=-0.16934649380265693, Observed=-0.28704759430186044
# Expected=-0.39331895510107784, Observed=-0.11419163572642788
# Expected=0.017121074685282622, Observed=0.028919917410753726
# Expected=0.14053416393807489, Observed=0.2643615055676847
# Expected=0.44663077901224574, Observed=0.7776634734334493
# Expected=1.1744672597659902, Observed=1.4892514713518281
# Expected=2.041810752256789, Observed=2.1598203988223332
# Expected=2.682970244321863, Observed=2.500239696426611
# Expected=2.7684117318613333, Observed=2.6124173262142776
# Expected=2.701455482734641, Observed=2.6083124227577272
# Expected=2.6060537758019957, Observed=2.5243178411577674
# Expected=2.459570990078848, Observed=2.422563478466543
# Expected=2.34348839131321, Observed=2.1923848355777906
# Expected=2.0142459990297947, Observed=1.7852376386070787
# Expected=1.4696013621497306, Observed=1.413196528289781
# Expected=1.1231690804661887, Observed=1.14708800563902
# Expected=0.9390382445260698, Observed=0.894415083270033
# Expected=0.6975518579508485, Observed=0.5721851288980915
# Expected=0.32175169943956017, Observed=0.23183761332010278
# Expected=-0.0331720327787961, Observed=0.1045358548094768
# Expected=0.0036937598383900427, Observed=-0.09770382328072458
# Expected=-0.2545988339407259, Observed=-0.014128598727111807
# Expected=0.04856695385399655, Observed=-0.04979896582924681
# Expected=-0.07650055163402363, Observed=0.00977324189221207
# Expected=0.05530867018221933, Observed=0.16482527652421197
# Expected=0.28477567440402063, Observed=0.2620902577712272
# Expected=0.33835276699389805, Observed=0.3049948412807595
# Expected=0.33886103054976124, Observed=0.32556116920097367
# Expected=0.3417569661311289, Observed=0.24542867775156907
# Expected=0.18388393871247832, Observed=0.08212910550201258
# Expected=-0.04435922921508437, Observed=-0.07347174575335913
# Expected=-0.19472784451616723, Observed=-0.15186589707020914
# Expected=-0.21355660046167452, Observed=-0.2578229569672317
# Expected=-0.34008597320789896, Observed=-0.27368306991255764
# Expected=-0.2868015608590336, Observed=-0.3739303598849588
# Expected=-0.4512591646450625, Observed=-0.41470609579058504
# Expected=-0.4469895883059778, Observed=-0.4307588108643188
# Expected=-0.44345564466165166, Observed=-0.4216746553139501
# Expected=-0.41481110751037625, Observed=-0.36986599036350754
# Expected=-0.32987902444768447, Observed=-0.5835216974209843
# Expected=-0.7475984474825453, Observed=-0.7713884571107883
# Expected=-0.9179598490717573, Observed=-0.857137189550258
# Expected=-0.9247684943024153, Observed=-0.8786538638028318
# Expected=-0.8959291143785643, Observed=-0.8926779947550969
# Expected=-0.903647602298923, Observed=-0.9796464392931341
# Expected=-1.0467423245523133, Observed=-1.1411214720304272
# Expected=-1.2662398740202119, Observed=-1.3599281618157164
# Expected=-1.5298451191912308, Observed=-1.5581393499743754
# Expected=-1.7126728561576068, Observed=-1.6581835646288923
# Expected=-1.736895906578522, Observed=-1.751173378792636
# Expected=-1.8236193265718805, Observed=-1.8997987502452318
# Expected=-2.0150670590482505, Observed=-1.8797212065087052
# Expected=-1.8655176104063063, Observed=-2.0914585017976606
# Expected=-2.254250247487049, Observed=-2.235908422587613
# Expected=-2.3490437653485046, Observed=-2.3642847602710475
# Expected=-2.4643815333196577, Observed=-2.382080640105407
# Expected=-2.3969097469645417, Observed=-2.3696747836781284
# Expected=-2.3602545498382685, Observed=-2.3273662091703997
# Expected=-2.2946780350486895, Observed=-2.3307157167877577
# Expected=-2.3329139090178463, Observed=-2.320340365584407
# Expected=-2.3123932928487374, Observed=-2.2522646304184235
# Expected=-2.199762964612015, Observed=-2.152521366337737
# Expected=-2.0751211908240133, Observed=-2.0833490498490193
# Expected=-2.029211461838069, Observed=-1.9415946816615772
# Expected=-1.8318572209181394, Observed=-1.8594612629202913
# Expected=-1.794961642964099, Observed=-1.744405607064067
# Expected=-1.6551188151084923, Observed=-1.5179157843041864
# Expected=-1.342512382118945, Observed=-1.2984389626626367
# Expected=-1.1274233623987495, Observed=-1.2241657951353417
# Expected=-1.1650559276395411, Observed=-1.2573231049628504
# Expected=-1.2822490722301076, Observed=-1.2857247225774202
# Expected=-1.3079035894962407, Observed=-1.3595353948101732
# Expected=-1.4166141564741463, Observed=-1.4664863728294506
# Expected=-1.5494928998997497, Observed=-1.5654766106185747
# Expected=-1.642633849239382, Observed=-1.6267883170275041
# Expected=-1.6748505892077141, Observed=-1.657083376840454
# Expected=-1.6809300750508653, Observed=-1.6898549094364697
# Expected=-1.7153447273281552, Observed=-1.6787231482574327
# Expected=-1.6704329754388854, Observed=-1.639702843649836
# Expected=-1.6095489711401076, Observed=-1.7021262193145503
# Expected=-1.74985766574493, Observed=-1.8082171692591018
# Expected=-1.8904736747944437, Observed=-1.9345480597369118
# Expected=-2.032752739695834, Observed=-2.0194563293735257
# Expected=-2.0859278400174914, Observed=-2.010316582457783
# Expected=-2.0039858256287295, Observed=-2.0584228595755647
# Expected=-2.095370639490826, Observed=-2.151629511339351
# Expected=-2.2238363278023443, Observed=-2.228852620141865
# Expected=-2.289126371745538, Observed=-2.2519892139883737
# Expected=-2.27045959393884, Observed=-2.2029709987514323
# Expected=-2.1654032383011073, Observed=-2.2240197361156433
# Expected=-2.2397997650955306, Observed=-2.2016047042942617
# Expected=-2.184535973068804, Observed=-2.185278343701512
# Expected=-2.1725047959947847, Observed=-2.154763065815999
# Expected=-2.131126042337546, Observed=-2.12145607526962
# Expected=-2.0955431200937547, Observed=-2.1334069393683883
# Expected=-2.142327081307669, Observed=-2.227745571475758
# Expected=-2.300509956057204, Observed=-2.2698884248763953

# %%
# Test and forecast set
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.plot(forecasts, color='red')
plt.show()

# %%
# Ensuring that data is one-dimensional
test = test.ravel()
forecasts = np.array(forecasts).ravel()

# %%
# Getting the high, low and close values ​​from the test set for the MACD
test_size_A = len(test)

close_test_A = base_A['Close/Last'].tail(test_size_A)

# %%
print(test.shape)
print(forecasts.shape)
# Out:
# (368,)
# (368,)

# %%
# Inverse MACD formula
def MACD_inverse_A(macd_values_A, close_values_A, short_window=12, long_window=26):
    original_prices = []
    for i in range(len(macd_values_A)):
        if i < long_window:
            original_prices.append(close_values_A[i])
            continue
        # Calculate moving averages
        short_ma = np.mean(close_values_A[max(0, i-short_window):i+1]) # Average of the last 'short_window' prices
        long_ma = np.mean(close_values_A[max(0, i-long_window):i+1])  # Average of the last 'long_window' prices
        # Estimate adjusted price
        estimated_price = close_values_A[i]
        price_adjustment = (macd_values_A[i] / 100) * (short_ma - long_ma) # Adjust based on difference
        estimated_price += price_adjustment
        original_prices.append(estimated_price)
    return np.array(original_prices)

# Making sure the data is in array format
close_test_A = close_test_A.values if isinstance(close_test_A, pd.Series) else close_test_A

# %%
test_inverted = MACD_inverse_A(test, close_test_A)
forecasts_inverted = MACD_inverse_A(forecasts, close_test_A)

min_length_R = min(len(test_R), len(forecasts_inverted))
test_R = test_R[:min_length_R]
forecasts_inverted = forecasts_inverted[:min_length_R]

# %%
# RMSE
rmse = sqrt(mean_squared_error(test_R, forecasts_inverted))
print(f'RMSE: {rmse}')

# R2 Score
r2 = r2_score(test_R, forecasts_inverted)
print(f'R2 Score: {r2}')
# Out:
# RMSE: 0.1505507704934205
# R2 Score: 0.9999434227558917

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(test_R)), test_R, label='Real')
plt.plot(range(len(forecasts_inverted)), forecasts_inverted, label='Prediction', color = 'red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
