# %% [markdown]
# #LSTM and ARIMA with Parabolic SAR Technical Indicator

# %% [markdown]
# **Authors:** Gabriel Sposito and Thomas Frentzel

# %% [markdown]
# **LSTM**

# %%
# !pip install ta

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, LSTM, Dense
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator

# %%
base = pd.read_csv('Intel 5Y.csv')
base.head()
# Out:
#          Date Close/Last    Volume    Open      High       Low
# 0  10/08/2024     $23.32  58650460  $22.25    $23.42   $22.045
# 1  10/07/2024     $22.38  54928670  $22.40    $22.65  $22.0209
# 2  10/04/2024     $22.59  49966930  $22.70    $22.91    $22.30
# 3  10/03/2024     $22.26  49565930  $22.14    $22.73    $21.65
# 4  10/02/2024     $22.39  59033900  $22.67  $23.0668    $22.35

# %%
# Removing nule results
base.dropna()
# Out:
#             Date Close/Last    Volume    Open      High       Low
# 0     10/08/2024     $23.32  58650460  $22.25    $23.42   $22.045
# 1     10/07/2024     $22.38  54928670  $22.40    $22.65  $22.0209
# 2     10/04/2024     $22.59  49966930  $22.70    $22.91    $22.30
# 3     10/03/2024     $22.26  49565930  $22.14    $22.73    $21.65
# 4     10/02/2024     $22.39  59033900  $22.67  $23.0668    $22.35
# ...          ...        ...       ...     ...       ...       ...
# 1253  10/15/2019     $52.65  18970760  $51.93    $53.07    $51.83
# 1254  10/14/2019     $51.64  16425530  $51.90    $51.95    $51.44
# 1255  10/11/2019     $52.09  24167110  $52.00    $52.79    $51.82
# 1256  10/10/2019     $51.11  14611660  $50.41   $51.775    $50.40
# 1257  10/09/2019     $50.48  12189960  $50.47    $50.79    $50.15
#
# [1258 rows x 6 columns]

# %%
# Removing $
base['Close/Last'] = base['Close/Last'].str.replace('$', '')
base['Open'] = base['Open'].str.replace('$', '')
base['High'] = base['High'].str.replace('$', '')
base['Low'] = base['Low'].str.replace('$', '')

# Converting str to float
base['Close/Last'] = base['Close/Last'].astype(float)
base['Open'] = base['Open'].astype(float)
base['High'] = base['High'].astype(float)
base['Low'] = base['Low'].astype(float)

# %%
cci = CCIIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'], window=20, constant=0.015)
base['CCI'] = cci.cci()

sma_tp = base['High'] + base['Low'] + base['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base['Close/Last'], window=14)
base['RSI'] = rsi.rsi()

macd = MACD(close=base['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base['MACD'] = macd.macd()
base['MACD_Signal'] = macd.macd_signal()
base['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base['High'], low=base['Low'], close=base['Close/Last'])
base['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base['Close/Last'], window=20, window_dev=2)
base['Bollinger_High'] = bollinger.bollinger_hband()
base['Bollinger_Low'] = bollinger.bollinger_lband()
base['Bollinger_Middle'] = bollinger.bollinger_mavg()
base['Bollinger_Width'] = bollinger.bollinger_wband()

base.dropna()
# Out:
#             Date  Close/Last    Volume    Open    High      Low         CCI  \
# 33    08/21/2024       21.41  57028870  21.072  21.440  21.0700  109.236141
# 34    08/20/2024       20.99  84161270  21.210  21.230  20.8200   82.525909
# 35    08/19/2024       21.52  65956300  20.885  21.860  20.8350  124.006703
# 36    08/16/2024       20.87  48582660  20.530  20.895  20.4101   57.383431
# 37    08/15/2024       20.69  84814880  20.320  21.060  20.2300   46.431701
# ...          ...         ...       ...     ...     ...      ...         ...
# 1253  10/15/2019       52.65  18970760  51.930  53.070  51.8300  -68.893127
# 1254  10/14/2019       51.64  16425530  51.900  51.950  51.4400  -81.645295
# 1255  10/11/2019       52.09  24167110  52.000  52.790  51.8200  -59.811562
# 1256  10/10/2019       51.11  14611660  50.410  51.775  50.4000  -83.377075
# 1257  10/09/2019       50.48  12189960  50.470  50.790  50.1500  -93.431049
#
#             RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    54.112274 -0.365474    -0.606827   0.241353      19.455067
# 34    51.262625 -0.290474    -0.543556   0.253082      19.561664
# 35    54.517618 -0.186125    -0.472070   0.285945      19.663997
# 36    50.098507 -0.154100    -0.408476   0.254376      19.762238
# 37    48.916029 -0.141612    -0.355103   0.213491      19.856548
# ...         ...       ...          ...        ...            ...
# 1253  32.656899 -1.587661    -1.307755  -0.279905      53.235976
# 1254  28.543524 -1.611303    -1.368465  -0.242838      53.070000
# 1255  32.615978 -1.575567    -1.409885  -0.165681      51.029100
# 1256  28.770423 -1.607790    -1.449466  -0.158323      52.790000
# 1257  26.599237 -1.664969    -1.492567  -0.172402      52.790000
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33         21.792245      18.378755          20.08550        16.994799
# 34         21.823466      18.369534          20.09650        17.186732
# 35         21.834038      18.363962          20.09900        17.264916
# 36         21.828382      18.365618          20.09700        17.230254
# 37         21.886088      18.410912          20.14850        17.247812
# ...              ...            ...               ...              ...
# 1253       60.363386      49.940114          55.15175        18.899260
# 1254       60.025053      49.607447          54.81625        19.004594
# 1255       59.591590      49.422910          54.50725        18.655647
# 1256       59.176915      49.143585          54.16025        18.525264
# 1257       58.804495      48.804005          53.80425        18.586804
#
# [1225 rows x 16 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(base['Parabolic_SAR'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base['Close/Last'], label='Real')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base = base.replace([np.inf, -np.inf], np.nan)
base = base.dropna()

# %%
# Normalizing the data of real values
scaler_real_value = MinMaxScaler(feature_range=(0, 1))
scaled_data_real_value = scaler_real_value.fit_transform(np.array(base['Close/Last']).reshape(-1, 1))

# %%
window_size_real_value = 10
forecasters_real_value = []
real_value_of_prices = []
for i in range(window_size_real_value, len(base)):
    forecasters_real_value.append(scaled_data_real_value[i - window_size_real_value:i, 0])
    real_value_of_prices.append(scaled_data_real_value[i, 0])

forecasters_real_value, real_value_of_prices = np.array(forecasters_real_value), np.array(real_value_of_prices)
forecasters_real_value = np.reshape(forecasters_real_value, (forecasters_real_value.shape[0], forecasters_real_value.shape[1], 1))

# %%
#dividindo a coluna close/last em 70% treino e 30% teste com trai_test_split
Xtrain_real_lstm, Xtest_real_lstm, ytrain_real_lstm, ytest_real_lstm = train_test_split(forecasters_real_value, real_value_of_prices,
                                                                                        test_size = 0.3, shuffle = False)

# %%
#plotando grafico dos valores de teste
plt.figure(figsize=(16,8))
plt.plot(ytest_real_lstm)
plt.show()

# %%
# Normalizing the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(base['Parabolic_SAR']).reshape(-1, 1))

# %%
window_size = 10
forecasters = []
real_value = []
for i in range(window_size, len(base)):
    forecasters.append(scaled_data[i - window_size:i, 0])
    real_value.append(scaled_data[i, 0])

forecasters, real_value = np.array(forecasters), np.array(real_value)
forecasters = np.reshape(forecasters, (forecasters.shape[0], forecasters.shape[1], 1))

# %%
# Separating data between training and testing
X_train, X_test, y_train, y_test = train_test_split(forecasters, real_value, test_size=0.3, shuffle=False)

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test)
plt.show()

# %%
# LSTM model

lstm = Sequential()
lstm.add(LSTM(units=50, return_sequences=True, input_shape=(forecasters.shape[1], 1)))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50, return_sequences=True))
lstm.add(Dropout(0.3))
lstm.add(LSTM(units=50))
lstm.add(Dropout(0.3))
lstm.add(Dense(units=1))
lstm.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = lstm.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 0.1011 - mean_absolute_error: 0.2504 - val_loss: 0.0317 - val_mean_absolute_error: 0.1602
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0126 - mean_absolute_error: 0.0929 - val_loss: 0.0095 - val_mean_absolute_error: 0.0804
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0682 - val_loss: 0.0068 - val_mean_absolute_error: 0.0649
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0067 - mean_absolute_error: 0.0627 - val_loss: 0.0065 - val_mean_absolute_error: 0.0628
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0063 - mean_absolute_error: 0.0603 - val_loss: 0.0065 - val_mean_absolute_error: 0.0634
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0605 - val_loss: 0.0066 - val_mean_absolute_error: 0.0642
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0583 - val_loss: 0.0065 - val_mean_absolute_error: 0.0625
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0055 - mean_absolute_error: 0.0574 - val_loss: 0.0078 - val_mean_absolute_error: 0.0709
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0060 - mean_absolute_error: 0.0611 - val_loss: 0.0063 - val_mean_absolute_error: 0.0625
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0056 - mean_absolute_error: 0.0585 - val_loss: 0.0061 - val_mean_absolute_error: 0.0608
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0056 - mean_absolute_error: 0.0593 - val_loss: 0.0063 - val_mean_absolute_error: 0.0630
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - mean_absolute_error: 0.0572 - val_loss: 0.0061 - val_mean_absolute_error: 0.0616
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0057 - mean_absolute_error: 0.0592 - val_loss: 0.0058 - val_mean_absolute_error: 0.0594
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0059 - mean_absolute_error: 0.0601 - val_loss: 0.0091 - val_mean_absolute_error: 0.0744
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0570 - val_loss: 0.0063 - val_mean_absolute_error: 0.0634
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0048 - mean_absolute_error: 0.0539 - val_loss: 0.0056 - val_mean_absolute_error: 0.0583
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0051 - mean_absolute_error: 0.0553 - val_loss: 0.0060 - val_mean_absolute_error: 0.0615
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0052 - mean_absolute_error: 0.0565 - val_loss: 0.0057 - val_mean_absolute_error: 0.0578
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0050 - mean_absolute_error: 0.0545 - val_loss: 0.0057 - val_mean_absolute_error: 0.0602
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0050 - mean_absolute_error: 0.0558 - val_loss: 0.0075 - val_mean_absolute_error: 0.0674
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0045 - mean_absolute_error: 0.0509 - val_loss: 0.0051 - val_mean_absolute_error: 0.0556
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0044 - mean_absolute_error: 0.0518 - val_loss: 0.0052 - val_mean_absolute_error: 0.0554
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0044 - mean_absolute_error: 0.0512 - val_loss: 0.0049 - val_mean_absolute_error: 0.0542
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0041 - mean_absolute_error: 0.0502 - val_loss: 0.0054 - val_mean_absolute_error: 0.0560
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0046 - mean_absolute_error: 0.0512 - val_loss: 0.0054 - val_mean_absolute_error: 0.0594
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0044 - mean_absolute_error: 0.0517 - val_loss: 0.0046 - val_mean_absolute_error: 0.0534
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0042 - mean_absolute_error: 0.0513 - val_loss: 0.0044 - val_mean_absolute_error: 0.0517
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0044 - mean_absolute_error: 0.0510 - val_loss: 0.0042 - val_mean_absolute_error: 0.0503
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0044 - mean_absolute_error: 0.0523 - val_loss: 0.0044 - val_mean_absolute_error: 0.0506
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0498 - val_loss: 0.0041 - val_mean_absolute_error: 0.0489
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0045 - mean_absolute_error: 0.0512 - val_loss: 0.0040 - val_mean_absolute_error: 0.0483
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - val_loss: 0.0041 - val_mean_absolute_error: 0.0508
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0482 - val_loss: 0.0037 - val_mean_absolute_error: 0.0463
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0038 - mean_absolute_error: 0.0466 - val_loss: 0.0049 - val_mean_absolute_error: 0.0540
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0038 - mean_absolute_error: 0.0475 - val_loss: 0.0043 - val_mean_absolute_error: 0.0496
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0037 - mean_absolute_error: 0.0458 - val_loss: 0.0037 - val_mean_absolute_error: 0.0459
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0499 - val_loss: 0.0033 - val_mean_absolute_error: 0.0445
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0033 - mean_absolute_error: 0.0459 - val_loss: 0.0047 - val_mean_absolute_error: 0.0570
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mean_absolute_error: 0.0486 - val_loss: 0.0033 - val_mean_absolute_error: 0.0434
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0422 - val_loss: 0.0051 - val_mean_absolute_error: 0.0565
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - mean_absolute_error: 0.0438 - val_loss: 0.0030 - val_mean_absolute_error: 0.0413
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0029 - mean_absolute_error: 0.0417 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0031 - mean_absolute_error: 0.0422 - val_loss: 0.0029 - val_mean_absolute_error: 0.0402
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0029 - mean_absolute_error: 0.0411 - val_loss: 0.0032 - val_mean_absolute_error: 0.0424
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0029 - mean_absolute_error: 0.0409 - val_loss: 0.0038 - val_mean_absolute_error: 0.0477
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0032 - mean_absolute_error: 0.0427 - val_loss: 0.0027 - val_mean_absolute_error: 0.0386
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0035 - mean_absolute_error: 0.0457 - val_loss: 0.0027 - val_mean_absolute_error: 0.0387
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0371 - val_loss: 0.0026 - val_mean_absolute_error: 0.0376
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - mean_absolute_error: 0.0384 - val_loss: 0.0032 - val_mean_absolute_error: 0.0426
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 0.0031 - val_mean_absolute_error: 0.0445
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0384 - val_loss: 0.0035 - val_mean_absolute_error: 0.0483
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mean_absolute_error: 0.0399 - val_loss: 0.0042 - val_mean_absolute_error: 0.0518
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0415 - val_loss: 0.0038 - val_mean_absolute_error: 0.0512
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0029 - mean_absolute_error: 0.0394 - val_loss: 0.0025 - val_mean_absolute_error: 0.0379
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0400 - val_loss: 0.0034 - val_mean_absolute_error: 0.0442
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - mean_absolute_error: 0.0362 - val_loss: 0.0027 - val_mean_absolute_error: 0.0401
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - mean_absolute_error: 0.0391 - val_loss: 0.0035 - val_mean_absolute_error: 0.0492
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0387 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0346 - val_loss: 0.0037 - val_mean_absolute_error: 0.0479
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0344 - val_loss: 0.0022 - val_mean_absolute_error: 0.0344
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0024 - mean_absolute_error: 0.0372 - val_loss: 0.0022 - val_mean_absolute_error: 0.0340
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0021 - val_mean_absolute_error: 0.0332
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0022 - mean_absolute_error: 0.0363 - val_loss: 0.0028 - val_mean_absolute_error: 0.0427
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0023 - mean_absolute_error: 0.0357 - val_loss: 0.0021 - val_mean_absolute_error: 0.0331
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0022 - mean_absolute_error: 0.0360 - val_loss: 0.0031 - val_mean_absolute_error: 0.0430
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0020 - mean_absolute_error: 0.0335 - val_loss: 0.0030 - val_mean_absolute_error: 0.0416
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0344 - val_loss: 0.0023 - val_mean_absolute_error: 0.0335
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0327 - val_loss: 0.0020 - val_mean_absolute_error: 0.0315
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0325 - val_loss: 0.0027 - val_mean_absolute_error: 0.0383
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - val_loss: 0.0035 - val_mean_absolute_error: 0.0476
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0340 - val_loss: 0.0035 - val_mean_absolute_error: 0.0477
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - mean_absolute_error: 0.0348 - val_loss: 0.0019 - val_mean_absolute_error: 0.0313
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0349 - val_loss: 0.0020 - val_mean_absolute_error: 0.0308
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0323 - val_loss: 0.0022 - val_mean_absolute_error: 0.0324
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0308 - val_loss: 0.0027 - val_mean_absolute_error: 0.0397
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0311 - val_loss: 0.0019 - val_mean_absolute_error: 0.0299
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0020 - mean_absolute_error: 0.0324 - val_loss: 0.0020 - val_mean_absolute_error: 0.0326
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 0.0018 - val_mean_absolute_error: 0.0299
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0313 - val_loss: 0.0019 - val_mean_absolute_error: 0.0297
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0299 - val_loss: 0.0018 - val_mean_absolute_error: 0.0285
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - val_loss: 0.0020 - val_mean_absolute_error: 0.0301
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0302 - val_loss: 0.0018 - val_mean_absolute_error: 0.0280
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0290 - val_loss: 0.0018 - val_mean_absolute_error: 0.0280
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 0.0020 - val_mean_absolute_error: 0.0307
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - val_loss: 0.0017 - val_mean_absolute_error: 0.0265
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0018 - mean_absolute_error: 0.0300 - val_loss: 0.0020 - val_mean_absolute_error: 0.0334
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0291 - val_loss: 0.0019 - val_mean_absolute_error: 0.0321
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0306 - val_loss: 0.0017 - val_mean_absolute_error: 0.0277
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - val_loss: 0.0018 - val_mean_absolute_error: 0.0287
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0017 - val_mean_absolute_error: 0.0263
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0314 - val_loss: 0.0016 - val_mean_absolute_error: 0.0259
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0297 - val_loss: 0.0019 - val_mean_absolute_error: 0.0305
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 0.0016 - val_mean_absolute_error: 0.0257
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0015 - mean_absolute_error: 0.0290 - val_loss: 0.0016 - val_mean_absolute_error: 0.0257
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0018 - val_mean_absolute_error: 0.0284
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0283 - val_loss: 0.0020 - val_mean_absolute_error: 0.0317
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 0.0020 - val_mean_absolute_error: 0.0316
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - val_loss: 0.0019 - val_mean_absolute_error: 0.0303

# %%
test_predictions = lstm.predict(X_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step

# %%
# Transforming test values ​​back to original values
y_orig_test = scaler.inverse_transform(y_test.reshape(-1, 1))

#escalonando valores de teste
ytest_real_lstm = scaler_real_value.inverse_transform(ytest_real_lstm.reshape(-1, 1))

# %%
test_predictions = test_predictions.ravel()  # Converts to 1D
y_orig_test = y_orig_test.ravel()
ytest_real_lstm = ytest_real_lstm.ravel()

# %%
test_size_L = len(y_test)

high_test_L = base['High'].tail(test_size_L)
low_test_L = base['Low'].tail(test_size_L)
close_test_L = base['Close/Last'].tail(test_size_L)

# %%
# Inverse Parabolic SAR formula
def inverse_psar(psar_values, high, low, close):
    original_prices = []

    original_prices.append(close[0])

    for i in range(1, len(psar_values)):
        if psar_values[i] < close[i-1]:
            estimated_price = close[i-1] + (close[i-1] - psar_values[i-1])
            estimated_price = min(estimated_price, high[i])
        else:
            estimated_price = close[i-1] - (psar_values[i-1] - close[i-1])
            estimated_price = max(estimated_price, low[i])

        original_prices.append(estimated_price)

    return np.array(original_prices)

# Making sure the data is in array format
high_test_L = high_test_L.values if isinstance(high_test_L, pd.Series) else high_test_L
low_test_L = low_test_L.values if isinstance(low_test_L, pd.Series) else low_test_L
close_test_L = close_test_L.values if isinstance(close_test_L, pd.Series) else close_test_L

# %%
# Inverting the values ​​test_predictions and y_orig_teste by the inverse Parabolic SAR formula
test_predictions_inverted = inverse_psar(test_predictions, high_test_L, low_test_L, close_test_L)
y_orig_test_inverted = inverse_psar(y_orig_test, high_test_L, low_test_L, close_test_L)

min_length = min(len(ytest_real_lstm), len(test_predictions_inverted))
ytest_real_lstm = ytest_real_lstm[:min_length]
test_predictions_inverted = test_predictions_inverted[:min_length]

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(ytest_real_lstm)), ytest_real_lstm, label='Real')
plt.plot(range(len(test_predictions_inverted)), test_predictions_inverted, label='Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# R2 Score
r2 = r2_score(ytest_real_lstm, test_predictions_inverted)
print(f'R2 Score: {r2}')

# RMSE
rmse = np.sqrt(np.mean((ytest_real_lstm - test_predictions_inverted) ** 2))
print(f'RMSE: {rmse}')
# Out:
# R2 Score: 0.9555945136460945
# RMSE: 1.231571142421454

# %% [markdown]
# **ARIMA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from ta.trend import CCIIndicator, MACD
from ta.momentum import RSIIndicator
from ta.volatility import BollingerBands
from ta.trend import PSARIndicator
from math import sqrt

# %%
base_A = pd.read_csv('Intel 5Y.csv')
base_A.head()
# Out:
#          Date Close/Last     Volume     Open     High        Low
# 0  10/08/2024    $132.89  285722500  $130.26  $133.48    $129.42
# 1  10/07/2024    $127.72  346250200  $124.99  $130.64    $124.95
# 2  10/04/2024    $124.92  244465600  $124.94  $125.04    $121.83
# 3  10/03/2024    $122.85  277118000  $120.92  $124.36  $120.3401
# 4  10/02/2024    $118.85  221845900  $116.44  $119.38    $115.14

# %%
base_A.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
# Removing $
base_A['Close/Last'] = base_A['Close/Last'].str.replace('$', '')
base_A['Open'] = base_A['Open'].str.replace('$', '')
base_A['High'] = base_A['High'].str.replace('$', '')
base_A['Low'] = base_A['Low'].str.replace('$', '')

# Converting str to float
base_A['Close/Last'] = base_A['Close/Last'].astype(float)
base_A['Open'] = base_A['Open'].astype(float)
base_A['High'] = base_A['High'].astype(float)
base_A['Low'] = base_A['Low'].astype(float)

# %%
cci = CCIIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'], window=20, constant=0.015)
base_A['CCI'] = cci.cci()

sma_tp = base_A['High'] + base_A['Low'] + base_A['Close/Last'] / 3
sma_tp = sma_tp.rolling(window=20).mean()
mean_deviation = np.mean(np.abs(base_A['Close/Last'] - sma_tp))

rsi = RSIIndicator(close=base_A['Close/Last'], window=14)
base_A['RSI'] = rsi.rsi()

macd = MACD(close=base_A['Close/Last'], window_slow=26, window_fast=12, window_sign=9)
base_A['MACD'] = macd.macd()
base_A['MACD_Signal'] = macd.macd_signal()
base_A['MACD_Diff'] = macd.macd_diff()

psar = PSARIndicator(high=base_A['High'], low=base_A['Low'], close=base_A['Close/Last'])
base_A['Parabolic_SAR'] = psar.psar()

bollinger = BollingerBands(close=base_A['Close/Last'], window=20, window_dev=2)
base_A['Bollinger_High'] = bollinger.bollinger_hband()
base_A['Bollinger_Low'] = bollinger.bollinger_lband()
base_A['Bollinger_Middle'] = bollinger.bollinger_mavg()
base_A['Bollinger_Width'] = bollinger.bollinger_wband()

base_A.dropna()
# Out:
#             Date  Close/Last    Volume    Open    High      Low         CCI  \
# 33    08/21/2024       21.41  57028870  21.072  21.440  21.0700  109.236141
# 34    08/20/2024       20.99  84161270  21.210  21.230  20.8200   82.525909
# 35    08/19/2024       21.52  65956300  20.885  21.860  20.8350  124.006703
# 36    08/16/2024       20.87  48582660  20.530  20.895  20.4101   57.383431
# 37    08/15/2024       20.69  84814880  20.320  21.060  20.2300   46.431701
# ...          ...         ...       ...     ...     ...      ...         ...
# 1253  10/15/2019       52.65  18970760  51.930  53.070  51.8300  -68.893127
# 1254  10/14/2019       51.64  16425530  51.900  51.950  51.4400  -81.645295
# 1255  10/11/2019       52.09  24167110  52.000  52.790  51.8200  -59.811562
# 1256  10/10/2019       51.11  14611660  50.410  51.775  50.4000  -83.377075
# 1257  10/09/2019       50.48  12189960  50.470  50.790  50.1500  -93.431049
#
#             RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33    54.112274 -0.365474    -0.606827   0.241353      19.455067
# 34    51.262625 -0.290474    -0.543556   0.253082      19.561664
# 35    54.517618 -0.186125    -0.472070   0.285945      19.663997
# 36    50.098507 -0.154100    -0.408476   0.254376      19.762238
# 37    48.916029 -0.141612    -0.355103   0.213491      19.856548
# ...         ...       ...          ...        ...            ...
# 1253  32.656899 -1.587661    -1.307755  -0.279905      53.235976
# 1254  28.543524 -1.611303    -1.368465  -0.242838      53.070000
# 1255  32.615978 -1.575567    -1.409885  -0.165681      51.029100
# 1256  28.770423 -1.607790    -1.449466  -0.158323      52.790000
# 1257  26.599237 -1.664969    -1.492567  -0.172402      52.790000
#
#       Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33         21.792245      18.378755          20.08550        16.994799
# 34         21.823466      18.369534          20.09650        17.186732
# 35         21.834038      18.363962          20.09900        17.264916
# 36         21.828382      18.365618          20.09700        17.230254
# 37         21.886088      18.410912          20.14850        17.247812
# ...              ...            ...               ...              ...
# 1253       60.363386      49.940114          55.15175        18.899260
# 1254       60.025053      49.607447          54.81625        19.004594
# 1255       59.591590      49.422910          54.50725        18.655647
# 1256       59.176915      49.143585          54.16025        18.525264
# 1257       58.804495      48.804005          53.80425        18.586804
#
# [1225 rows x 16 columns]

# %%
# Converting indicator values ​​to numeric values ​​and removing NaN values
base_A = base_A.replace([np.inf, -np.inf], np.nan)
base_A = base_A.dropna()

# %%
base_A.head()
# Out:
#           Date  Close/Last     Volume     Open    High     Low         CCI  \
# 33  08/21/2024      128.50  257883600  127.315  129.35  126.66  109.563550
# 34  08/20/2024      127.25  300087400  128.400  129.88  125.89   93.439821
# 35  08/19/2024      130.00  318333600  124.280  130.00  123.42   85.454132
# 36  08/16/2024      124.58  302589900  121.940  125.00  121.18   43.621331
# 37  08/15/2024      122.86  318086700  118.760  123.24  117.47   20.947193
#
#           RSI      MACD  MACD_Signal  MACD_Diff  Parabolic_SAR  \
# 33  59.206678  1.479949    -0.959813   2.439762     115.264796
# 34  57.552758  1.795072    -0.408836   2.203908     117.184220
# 35  60.187685  2.240879     0.121107   2.119773     118.873314
# 36  53.180795  2.132257     0.523337   1.608920     120.359716
# 37  51.145899  1.885647     0.795799   1.089848     131.260000
#
#     Bollinger_High  Bollinger_Low  Bollinger_Middle  Bollinger_Width
# 33      133.280229     100.584771          116.9325        27.960967
# 34      134.480982     100.772018          117.6265        28.657628
# 35      136.004529     100.689471          118.3470        29.840264
# 36      136.582416     100.891584          118.7370        30.058729
# 37      136.860746     100.989254          118.9250        30.163121

# %%
# Plotting Parabolic SAR
plt.figure(figsize=(16,8))
plt.plot(base_A['Parabolic_SAR'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.plot(base_A['Close/Last'], label='Real')
plt.ylabel('Price')
plt.legend()

# %%
X_R = base_A['Close/Last'].values
size_R = int(len(X_R) * 0.70)
train_R, test_R = X_R[0:size_R], X_R[size_R:len(X_R)]
history_R = [x_r for x_r in train_R]
forecasts_R = list()

# %%
#Test Grafic
plt.figure(figsize=(16, 8))
plt.plot(test_R)
plt.show()

# %%
#Addfuller for Parabolic_SAR
result = adfuller(base_A['Parabolic_SAR'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -2.429277117841055
# p-value: 0.13364306334767817

# %%
plot_acf(base_A['Parabolic_SAR'], lags=40)
plt.show()

# %%
plot_pacf(base_A['Parabolic_SAR'], lags=40)
plt.show()

# %%
X = base_A['Parabolic_SAR'].values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
forecasts = list()

# %%
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.show()

# %%
# ARIMA
for t in range(len(test)):
    model = ARIMA(history, order=(2, 1, 1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    forecasts.append(yhat)
    obs = test[t]
    history.append(obs)
    print(f'Expected={yhat}, Observed={obs}')
# Out:
# Expected=14.799350106453055, Observed=14.537034490374273
# Expected=14.4307183898127, Observed=14.17462897191439
# Expected=14.057742745530945, Observed=13.870208336408087
# Expected=13.75733243954059, Observed=13.614495002582792
# Expected=13.512205756635627, Observed=13.399695802169546
# Expected=13.309969690826959, Observed=13.3945
# Expected=13.345905413899215, Observed=12.272
# Expected=12.06340780512577, Observed=12.295626
# Expected=12.182131516715225, Observed=12.34430096
# Expected=12.294808691145416, Observed=12.3910289216
# Expected=12.374002545655955, Observed=12.435887764736
# Expected=12.435043223557486, Observed=13.5125
# Expected=13.688767788156749, Observed=13.491399999999999
# Expected=13.588422130178053, Observed=13.434116
# Expected=13.473798350164566, Observed=13.32205904
# Expected=13.323301339834408, Observed=13.216725497599999
# Expected=13.198985697004826, Observed=11.5665
# Expected=11.286274081159032, Observed=11.604199999999999
# Expected=11.451245585086726, Observed=11.696851999999998
# Expected=11.63484139976641, Observed=11.830540879999997
# Expected=11.821891887220827, Observed=11.956208427199998
# Expected=11.97374226690529, Observed=12.149695753023998
# Expected=12.191526703104781, Observed=12.385406177721599
# Expected=12.447161708649286, Observed=12.597545559949438
# Expected=12.665984702694837, Observed=12.901836092755506
# Expected=12.988505294509153, Observed=13.220359039769734
# Expected=13.319556864700631, Observed=13.494288774201971
# Expected=13.592697825107217, Observed=13.770962570329656
# Expected=13.868971854842957, Observed=14.059239307670317
# Expected=14.158982708726764, Observed=14.29562623228966
# Expected=14.38788048867151, Observed=15.3725
# Expected=15.59810609044261, Observed=15.351878000000001
# Expected=15.474066643888301, Observed=15.306702880000001
# Expected=15.361082915898017, Observed=15.2119327072
# Expected=15.22354062123166, Observed=15.078642090624001
# Expected=15.061733276664715, Observed=14.9045678815616
# Expected=14.866122258372355, Observed=14.74790109340544
# Expected=14.70096271076327, Observed=14.572412962196788
# Expected=14.518265632412112, Observed=14.338667147489238
# Expected=14.271130741859517, Observed=14.137645746840745
# Expected=14.068071781257121, Observed=13.964767342283041
# Expected=13.899102600781806, Observed=13.777412567517754
# Expected=13.711648993960992, Observed=12.7938
# Expected=12.597411842044696, Observed=12.814494
# Expected=12.708081931272805, Observed=12.85558224
# Expected=12.808559820062735, Observed=12.9242113056
# Expected=12.912025164016022, Observed=13.9994
# Expected=14.170047612992777, Observed=13.976291999999999
# Expected=14.070164376094354, Observed=13.95364616
# Expected=13.997244178013254, Observed=13.9314532368
# Expected=13.94967546548465, Observed=13.909704172064
# Expected=13.915146223311039, Observed=12.844
# Expected=12.672065594262211, Observed=12.86634
# Expected=12.771780431593037, Observed=13.961
# Expected=14.092659426821315, Observed=13.93951
# Expected=14.013677441463397, Observed=13.8853696
# Expected=13.913917056967723, Observed=13.833394816
# Expected=13.838840496156887, Observed=13.783499023360001
# Expected=13.777582012148043, Observed=13.735599062425601
# Expected=13.724262439143471, Observed=13.689615099928577
# Expected=13.675861300186352, Observed=13.645470495931434
# Expected=13.630809945748435, Observed=13.603091676094177
# Expected=13.588278109189517, Observed=13.56240800905041
# Expected=13.547811660747216, Observed=13.523351688688393
# Expected=13.509148662285297, Observed=13.485857621140857
# Expected=13.472125971641983, Observed=13.449863316295223
# Expected=13.436631788156062, Observed=13.415308783643415
# Expected=13.402581532936177, Observed=12.586
# Expected=12.443466637816355, Observed=12.603026
# Expected=12.525246439840169, Observed=12.637464959999999
# Expected=12.60379671876579, Observed=12.670526361599999
# Expected=12.659188514682668, Observed=12.702265307135999
# Expected=12.702031741979232, Observed=12.732734694850558
# Expected=12.737916320250443, Observed=12.761985307056536
# Expected=12.769703414143883, Observed=12.812194188633145
# Expected=12.824617114413545, Observed=12.885722653542492
# Expected=12.904557036407104, Observed=12.953368841259094
# Expected=12.974725983416924, Observed=13.015603333958365
# Expected=13.037297264822099, Observed=13.072859067241696
# Expected=13.093855743324893, Observed=13.7313
# Expected=13.850276605697104, Observed=13.716121999999999
# Expected=13.780556161258117, Observed=13.701247559999999
# Expected=13.73136617308695, Observed=13.686670608799998
# Expected=13.699425617640749, Observed=13.654603784447998
# Expected=13.65568627968797, Observed=13.623819633070077
# Expected=13.61901416923235, Observed=13.594266847747274
# Expected=13.586687089086183, Observed=12.885
# Expected=12.76480368579566, Observed=12.899416
# Expected=12.833727227970375, Observed=12.91354368
# Expected=12.882665192003872, Observed=12.9429819328
# Expected=12.932268062686248, Observed=12.986525016832001
# Expected=12.988504439631663, Observed=13.766
# Expected=13.894977972948459, Observed=13.766
# Expected=13.839201730097562, Observed=12.6283
# Expected=12.47920159295988, Observed=12.6283
# Expected=12.541653676310586, Observed=12.669564
# Expected=12.632305467305478, Observed=12.710002719999999
# Expected=12.69807981584129, Observed=14.6915
# Expected=15.010114070394216, Observed=14.649726
# Expected=14.823689821778382, Observed=14.559536959999999
# Expected=14.632621143252647, Observed=14.423964742399999
# Expected=14.43804552249248, Observed=14.296526857856
# Expected=14.28154702583595, Observed=14.17673524638464
# Expected=14.14833155190855, Observed=14.064131131601561
# Expected=14.030162795276697, Observed=13.958283263705468
# Expected=13.922663866501242, Observed=13.85878626788314
# Expected=13.823431341878479, Observed=12.3
# Expected=12.026251011001875, Observed=12.329830000000001
# Expected=12.180763701888953, Observed=12.388628800000001
# Expected=12.32290111139478, Observed=12.484321072
# Expected=12.467163665660308, Observed=12.61529538624
# Expected=12.62891027254056, Observed=12.7357917553408
# Expected=12.76364629925165, Observed=12.89649257980672
# Expected=12.938039900426388, Observed=13.070733470229914
# Expected=13.121826585909128, Observed=13.224065453802325
# Expected=13.276716510047539, Observed=13.358997599346045
# Expected=13.409231296106562, Observed=13.477737887424519
# Expected=13.523924057083608, Observed=13.582229340933576
# Expected=13.623878591210469, Observed=14.3485
# Expected=14.495861543130141, Observed=14.325986
# Expected=14.40446663740026, Observed=14.27498656
# Expected=14.306253532793018, Observed=14.226027097600001
# Expected=14.233400646316253, Observed=14.179026013696001
# Expected=14.174615882826034, Observed=14.10428245287424
# Expected=14.089380066458661, Observed=13.995939856644302
# Expected=13.969957769864964, Observed=13.820925870979872
# Expected=13.778105462324826, Observed=13.604094766462287
# Expected=13.545254481065172, Observed=13.413283394486813
# Expected=13.350162151005605, Observed=13.245369387148395
# Expected=13.18406764966195, Observed=13.05764767294762
# Expected=12.99425090804843, Observed=12.896206998734954
# Expected=12.835849414215552, Observed=11.9045
# Expected=11.710201302415268, Observed=11.928266
# Expected=11.8239688662277, Observed=11.98308736
# Expected=11.93937009823648, Observed=13.315
# Expected=13.511184563650488, Observed=13.315
# Expected=13.427250282164497, Observed=13.286615999999999
# Expected=13.338851883863818, Observed=13.25879968
# Expected=13.280463512934118, Observed=13.196619692799999
# Expected=13.197174843669139, Observed=11.7043
# Expected=11.46006928857468, Observed=11.7048
# Expected=11.56674508596976, Observed=11.825676
# Expected=11.775554933079967, Observed=11.941716959999999
# Expected=11.93644590647801, Observed=12.0531162816
# Expected=12.069759267827074, Observed=12.160059630335999
# Expected=12.187028550469982, Observed=12.262725245122558
# Expected=12.294181480495613, Observed=12.361284235317656
# Expected=12.394300996814936, Observed=12.45590086590495
# Expected=12.48902470443811, Observed=14.7267
# Expected=15.115450422978016, Observed=14.67607
# Expected=14.886729938277618, Observed=14.5641792
# Expected=14.651988207921628, Observed=14.456764032
# Expected=14.48262755080393, Observed=14.35364547072
# Expected=14.348878703662317, Observed=14.2014587424768
# Expected=14.173216393409115, Observed=13.980582043078657
# Expected=13.928775793177232, Observed=13.71810383877079
# Expected=13.646916499709079, Observed=13.386927378118296
# Expected=13.294310277360784, Observed=13.024169545181735
# Expected=12.914873531684814, Observed=12.712197808856292
# Expected=12.60243219543501, Observed=12.44390211561641
# Expected=12.34151324879462, Observed=12.213167819430113
# Expected=12.121063181671202, Observed=12.014736324709897
# Expected=11.933472110760713, Observed=11.844085239250512
# Expected=11.773155439281393, Observed=11.66347960097043
# Expected=11.596422742753276, Observed=11.441993272795752
# Expected=11.370121680366099, Observed=11.212654618236602
# Expected=11.136662570867333, Observed=11.029183694589282
# Expected=10.958516368976028, Observed=10.865206955671425
# Expected=10.800861691851402, Observed=10.73402556453714
# Expected=10.678425362367904, Observed=9.777
# Expected=9.591245937213767, Observed=9.777
# Expected=9.67361376103116, Observed=9.81002
# Expected=9.763039265631015, Observed=9.8417192
# Expected=9.82341298741122, Observed=9.872150432
# Expected=9.868151910347676, Observed=10.6025
# Expected=10.720035278723403, Observed=10.58836
# Expected=10.652675567311835, Observed=10.5745028
# Expected=10.604664989100334, Observed=9.7855
# Expected=9.671807232558466, Observed=9.7855
# Expected=9.720296190823824, Observed=9.805634000000001
# Expected=9.77591105008829, Observed=9.825365320000001
# Expected=9.813730553451714, Observed=9.844702013600001
# Expected=9.842157989399123, Observed=10.7922
# Expected=10.945782013460676, Observed=10.770605999999999
# Expected=10.854021373355296, Observed=10.722913759999999
# Expected=10.757133394277332, Observed=10.6443189344
# Expected=10.64835016968453, Observed=10.534093419648
# Expected=10.5173809051395, Observed=10.370684077683201
# Expected=10.33448434473175, Observed=10.223615669914881
# Expected=10.17970428934931, Observed=10.091254102923394
# Expected=10.045998619344557, Observed=9.972128692631054
# Expected=9.92849582676581, Observed=9.86491582336795
# Expected=9.824176642732738, Observed=9.768424241031155
# Expected=9.731014804248332, Observed=9.68158181692804
# Expected=9.647536356589661, Observed=9.603423635235236
# Expected=9.572591684510064, Observed=9.533081271711712
# Expected=9.505235638428609, Observed=9.449767519106306
# Expected=9.421391542377304, Observed=9.350932066431422
# Expected=9.319627661680533, Observed=8.7033
# Expected=8.580766293801563, Observed=8.7033
# Expected=8.634989521579811, Observed=8.735168
# Expected=8.705796599131109, Observed=9.5
# Expected=9.61033086826601, Observed=9.483716
# Expected=9.54428691000316, Observed=9.46775768
# Expected=9.495639950796443, Observed=9.4361473728
# Expected=9.444942714902238, Observed=9.405801477888001
# Expected=9.40499324484761, Observed=9.360933389214722
# Expected=9.352907188173273, Observed=9.318757385861838
# Expected=9.307377728599743, Observed=9.25205679499289
# Expected=9.235003149505966, Observed=9.164781115493602
# Expected=9.141260549804922, Observed=7.9968
# Expected=7.793369432487145, Observed=7.9968
# Expected=7.88254405852467, Observed=8.020498
# Expected=7.966569853542743, Observed=8.04372204
# Expected=8.02045544020856, Observed=8.066481599200001
# Expected=8.058648837966649, Observed=8.088785967216001
# Expected=8.088683263026327, Observed=9.1817
# Expected=9.360239980852146, Observed=9.155546
# Expected=9.252226357656951, Observed=9.096824159999999
# Expected=9.135861847684394, Observed=9.006702710399999
# Expected=9.011167870590437, Observed=8.921988547776
# Expected=8.909547449258461, Observed=8.84235723490944
# Expected=8.822249492461701, Observed=8.767503800814874
# Expected=8.744348813777396, Observed=8.668751496749683
# Expected=8.640203201506711, Observed=8.540406347074715
# Expected=8.504069831478837, Observed=8.38943358542575
# Expected=8.345178143240144, Observed=8.197992883466144
# Expected=8.142908408184171, Observed=8.009690022111561
# Expected=7.949245379138291, Observed=7.851515618573711
# Expected=7.793305820038229, Observed=7.718649119601918
# Expected=7.665991710557707, Observed=7.607041260465611
# Expected=7.560906521057614, Observed=7.605
# Expected=7.580251253779245, Observed=7.5875
# Expected=7.5721105190723055, Observed=7.48445
# Expected=7.459681648304747, Observed=7.36456
# Expected=7.331467070919362, Observed=6.6778
# Expected=6.547814318105855, Observed=6.6778
# Expected=6.60537568764958, Observed=6.709548000000001
# Expected=6.678105903137567, Observed=6.755475120000001
# Expected=6.747378519436698, Observed=6.798646612800001
# Expected=6.802044303967532, Observed=7.475
# Expected=7.587520665808554, Observed=7.454
# Expected=7.514062276167067, Observed=7.43342
# Expected=7.460215533826202, Observed=7.4132516
# Expected=7.423305477266205, Observed=7.393486568
# Expected=7.3951469707233475, Observed=7.35067910528
# Expected=7.3443406006212895, Observed=7.2672203589632005
# Expected=7.249980353013633, Observed=7.188769137425409
# Expected=7.1664382291120186, Observed=7.115024989179884
# Expected=7.090937513087082, Observed=7.045705489829091
# Expected=7.021497932912365, Observed=6.980545160439346
# Expected=6.956998669135521, Observed=6.919294450812985
# Expected=6.896760579114042, Observed=6.861718783764206
# Expected=6.840334536058204, Observed=6.807597656738354
# Expected=6.787394029392314, Observed=6.719093844199286
# Expected=6.693910225804923, Observed=6.543484459779357
# Expected=6.501233005772989, Observed=6.385436013801422
# Expected=6.336569496983916, Observed=6.199347692145251
# Expected=6.14273073599874, Observed=5.9638190152449155
# Expected=5.894943129815369, Observed=5.761264353110628
# Expected=5.691080264414594, Observed=4.517
# Expected=4.2763499227009945, Observed=4.54717
# Expected=4.418210402380867, Observed=4.5767366
# Expected=4.516678243554169, Observed=4.650267136
# Expected=4.632200024465218, Observed=4.76287110784
# Expected=4.772841370290471, Observed=4.8687188413696
# Expected=4.8921391193242645, Observed=5.015997334060032
# Expected=5.052911153455635, Observed=5.222397600654029
# Expected=5.276186843965643, Observed=5.450385888575545
# Expected=5.516811028904704, Observed=5.65101558194648
# Expected=5.7195755831465585, Observed=5.827569712112902
# Expected=5.893011595359661, Observed=5.982937346659354
# Expected=6.043109710407534, Observed=6.0448
# Expected=6.0868363422745215, Observed=6.1741
# Expected=6.217060348481982, Observed=6.287884
# Expected=6.329443338611289, Observed=6.38801392
# Expected=6.426483808327486, Observed=6.5618919712
# Expected=6.610706148422578, Observed=6.777269255808
# Expected=6.838814920673061, Observed=6.95818617487872
# Expected=7.020951776272069, Observed=7.110156386898125
# Expected=7.16847557431663, Observed=7.908
# Expected=8.069275129397468, Observed=7.884396000000001
# Expected=7.969937536372124, Observed=7.83746816
# Expected=7.872805413289653, Observed=7.7644680704
# Expected=7.769950666782008, Observed=7.647910624768
# Expected=7.630930814303868, Observed=7.5095495622912
# Expected=7.477227746864063, Observed=7.355043614816256
# Expected=7.312117035842667, Observed=7.19126550874198
# Expected=7.141305837167181, Observed=7.016743027343263
# Expected=6.9613820778226705, Observed=6.813263282421476
# Expected=6.750336238511415, Observed=6.62437062593718
# Expected=6.559713242071197, Observed=6.473256500749744
# Expected=6.414036458088988, Observed=6.352365200599795
# Expected=6.301201087463448, Observed=6.255652160479836
# Expected=6.212805997530247, Observed=5.8057
# Expected=5.709606598927564, Observed=5.8057
# Expected=5.75267820100848, Observed=5.819336
# Expected=5.794764120613504, Observed=5.83269928
# Expected=5.822596778153255, Observed=5.8457952944
# Expected=5.842960366009155, Observed=5.858629388512
# Expected=5.859421814805853, Observed=5.87120680074176
# Expected=5.87378804928224, Observed=5.883532664726925
# Expected=5.8869744102489285, Observed=5.8956120114323864
# Expected=5.89944593403878, Observed=5.907449771203739
# Expected=5.911440026730783, Observed=5.919050775779664
# Expected=5.923079000433846, Observed=5.930419760264071
# Expected=5.934426950821258, Observed=6.4875
# Expected=6.580606781595421, Observed=6.475944
# Expected=6.526627325691672, Observed=6.44817824
# Expected=6.469145431105458, Observed=6.4215231104
# Expected=6.427495244493851, Observed=6.395934185984
# Expected=6.39451121695125, Observed=6.3573761348249604
# Expected=6.3501081794083385, Observed=6.321131566735463
# Expected=6.311158832115359, Observed=6.287061672731335
# Expected=6.276099745624588, Observed=6.255035972367455
# Expected=6.243929258233721, Observed=6.224931814025408
# Expected=6.214085989482102, Observed=6.196633905183884
# Expected=6.186233856812083, Observed=6.17003387087285
# Expected=6.160154210855367, Observed=6.14502983862048
# Expected=6.135690575140911, Observed=6.112131451530842
# Expected=6.101792068571837, Observed=6.064718306377758
# Expected=6.051425304653939, Observed=6.011268109612427
# Expected=5.995352901446313, Observed=5.946060574266687
# Expected=5.926840427614637, Observed=5.857970882384017
# Expected=5.83322750682082, Observed=5.767886123554894
# Expected=5.739798785416758, Observed=5.670608898843915
# Expected=5.63963688044168, Observed=5.590987119075132
# Expected=5.561368702587119, Observed=5.527289695260106
# Expected=5.501130283426884, Observed=5.459371756208085
# Expected=5.434428821130893, Observed=5.405037404966468
# Expected=5.3828856407116925, Observed=5.0093
# Expected=4.932941001665428, Observed=5.0093
# Expected=4.966787667292513, Observed=5.027068
# Expected=5.008481152262043, Observed=5.0555219199999994
# Expected=5.050949027035679, Observed=5.0924561664
# Expected=5.0964574042888495, Observed=5.13674054976
# Expected=5.1463597604312765, Observed=5.1765964947839995
# Expected=5.188404870504833, Observed=5.5353
# Expected=5.600238204729711, Observed=5.527876
# Expected=5.56303702468633, Observed=5.51241296
# Expected=5.527585277008148, Observed=5.4873261823999995
# Expected=5.49074508016314, Observed=5.449612087807999
# Expected=5.444933238424664, Observed=5.414915120783359
# Expected=5.406511195909722, Observed=5.38299391112069
# Expected=5.3731904102790535, Observed=5.353626398231035
# Expected=5.343560012610297, Observed=5.326608286372553
# Expected=5.316817948751317, Observed=5.301751623462748
# Expected=5.292477002666005, Observed=5.2925
# Expected=5.286055612558387, Observed=5.0159
# Expected=4.9673845128197245, Observed=5.021352
# Expected=4.994981978409091, Observed=5.2885
# Expected=5.318851407638599, Observed=5.282026
# Expected=5.298948584637338, Observed=5.26855696
# Expected=5.27484727373323, Observed=5.2556266816
# Expected=5.256561900913337, Observed=5.243213614336
# Expected=5.241531746260866, Observed=5.23129706976256
# Expected=5.228378507387307, Observed=5.2225
# Expected=5.2194705994157475, Observed=5.2022200000000005
# Expected=5.197290315813516, Observed=5.1681064
# Expected=5.159843877219375, Observed=5.136721888
# Expected=5.127083722312098, Observed=5.10784813696
# Expected=5.097951533334046, Observed=5.065813323264001
# Expected=5.053661754546155, Observed=5.027981990937601
# Expected=5.015247001466817, Observed=4.9939337918438405
# Expected=4.981563134272999, Observed=4.9805
# Expected=4.971717047549572, Observed=4.9823
# Expected=4.978021697623466, Observed=4.937576
# Expected=4.9281283409477785, Observed=4.87775736

# %%
# Test and forecast set
plt.figure(figsize=(16, 8))
plt.plot(test)
plt.plot(forecasts, color='red')
plt.show()

# %%
# Ensuring that data is one-dimensional
test = test.ravel()
forecasts = np.array(forecasts).ravel()

# %%
# Getting the high, low and close values ​​from the test set for the Parabolic SAR
test_size_A = len(test)

high_test_A = base_A['High'].tail(test_size_A)
low_test_A = base_A['Low'].tail(test_size_A)
close_test_A = base_A['Close/Last'].tail(test_size_A)

# %%
print(test.shape)
print(forecasts.shape)
# Out:
# (368,)
# (368,)

# %%
# Inverse Parabolic SAR formula
def inverse_psar_A(psar_values_A, high_A, low_A, close_A):
    original_prices = []

    original_prices.append(close_A[0])

    for i in range(1, len(psar_values_A)):
        if psar_values_A[i] < close_A[i-1]:
            estimated_price = close_A[i-1] + (close_A[i-1] - psar_values_A[i-1])
            estimated_price = min(estimated_price, high_A[i])
        else:
            estimated_price = close_A[i-1] - (psar_values_A[i-1] - close_A[i-1])
            estimated_price = max(estimated_price, low_A[i])

        original_prices.append(estimated_price)

    return np.array(original_prices)

# Making sure the data is in array format
high_test_A = high_test_A.values if isinstance(high_test_A, pd.Series) else high_test_A
low_test_A = low_test_A.values if isinstance(low_test_A, pd.Series) else low_test_A
close_test_A = close_test_A.values if isinstance(close_test_A, pd.Series) else close_test_A

# %%
test_inverted = inverse_psar_A(test, high_test_A, low_test_A, close_test_A)
forecasts_inverted = inverse_psar_A(forecasts, high_test_A, low_test_A, close_test_A)

min_length_R = min(len(test_R), len(forecasts_inverted))
test_R = test_R[:min_length_R]
forecasts_inverted = forecasts_inverted[:min_length_R]

# %%
# RMSE
rmse = sqrt(mean_squared_error(test_R, forecasts_inverted))
print(f'RMSE: {rmse}')

# R2 Score
r2 = r2_score(test_R, forecasts_inverted)
print(f'R2 Score: {r2}')
# Out:
# RMSE: 0.29707246216269345
# R2 Score: 0.9922004960288178

# %%
plt.figure(figsize=(16, 8))
plt.plot(range(len(test_R)), test_R, label='Real')
plt.plot(range(len(forecasts_inverted)), forecasts_inverted, label='Prediction', color = 'red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
